# %% [markdown]
# # Machine Learning - Crime Predictor
# In this notebook we use supervised machine learning to create a binary classifier to predict whether an area has high or low levels of serious violent crime, based on the characteristics (or features) of the areas experiencing those crimes.
#
# ### Random Forests
# The specific technique we employ is an ensemble machine learning method called Random Forests.
# - In Random Forests, data is passed through many ‘bags’ of independently created Decision Trees and the chosen result is the outcome that is selected most frequently across all the trees in the forest.
#     - In simple decision trees, the machine learning algorithm traverses the tree, starting at its root and at each node deduces which branch to take based on the outcome of a logical comparison with values in the data being assessed. It then terminates at the node representing most appropriate target outcome given the data values. This is the predicted value.
#     - In Random Forests, the algorithms randomly creates hundreds/thousands of Decision Trees, with each based on different features, randomly selected
#     - Random Forests have been found to be far less prone to overfitting than Decision Trees which means they have improved predictive accuracy for unseen data.
#
# ### Feature Engineering
# A fundemental step in creating a Random Forest classifier is engineering the features used train it. This is for two prime reasons:
# - to reduce overfitting - while Random Forests are less prone to overfitting, it still has some affect and this decreases the accuracy of the predictions. Reducing the number of features used to train the model helps reduce the extent to which it overfits. We use two approaches to identify which features to prune:
#     - check for correlation among features and remove subsets of features which are highly correlated
#     - assess the relative importance of features in producing classification results and remove less important features
# - to improve prediction performance by resolving imbalance in the data. Unbalanced datasets are datasets where one target value occurs far more frequently than the other, and such data can lead to poor performance in binary classsifiers because we observe too many false positives for the majority case and too many false negatives for the minority case. For example, VANHOEYVELD, J. and MARTENS, D., (2018) explain how classifiers training with unbalanced data result in models which "emphasize the majority class instances at the expense of neglecting minority class examples, while the latter is usually the phenomenon of interest”.
#     - We may encounter this because we will be creating snapshots of 1000 and 2000 high crime labels and remainder of nearly 5000 LSOAs will therefore be low crime. We will therefore use the SMOTE algorithm so we can check performance with and without rebalancing:
#     - Synthetic Minority Over-sampling Technique (SMOTE): As discussed by Chawla et al (Chawla, N.V., Bowyer, K.W., Hall, L.O. and Kegelmeyer, W.P., 2002., SMOTE rebalances datasets by under-sampling instances resolving to the majority class and oversampling instances resolving to the minority class and using this approach outperformed approaches that purely under-sampled the majority class.
#
# ### Cross validation and hyperparameters
# Having identified which features and cohort size give us the best results, we now want to derive the best random forest model configuration and to do this we test model performance given different hyperparameter configurations. We will use a grid search approach, so that we can automate the training of models using different hyperparamter combinations. We will also use cross validation in the training process as this is another key way to reduce model overfitting.
#
# ### Model performance
# THere is no one single measure we can use to conclude a model is good and so we use a range of measures, which we describe below (these descriptions have been taken from Neural Network coursework previously submitted by Phil Moura). However, the <b> measures we will place most importance on are the Area under the Curve (AUC), which tells us how well our model differentiates between low and high crime areas and the Recall, which tells us how good our model is at predicting a high crime area.</b>
#
# Performance Measures:
# - True positive – the model correctly predicts a positive outcome
# - True negative – the model correctly predicts a negative outcome
# - False positive – the model predicts a positive outcome when the real outcome was negative
# - False negative – the model predicts a negative outcome when the real outcome was positive
# - Precision: The percentage of correctly predicted positives verses all predicted positives
# - Recall: Of all positive outcomes within test dataset, how many were predicted correctly by the model
# - Confusion Matrix: a matrix showing actual outcomes versus predicted outcomes and specifies the number of true positives, true negatives, false positives and false negatives
# - ROC Curve and Area Under the Curve: Both reflect how good the model differentiates between our two classes. A model whose performance produces an ROC curve that is a 45% line and which has a 50% AUC has no predictive ability.
#
#
# ## Method
#
# - 1. Load data and identify highly correlated features
# Load the violencefeatures_master data created previously and then derive correlations across all numeric features to identify features which are most highly correlated
#
# - 2. Perform Random Forest training experiments
#
#     Perform a number of experiments whereby we train models with different cohort sizes and features, unbalanced and rebalanced and then assess the performance of these models
#     Identifying feature importance is a step within these experiments and so, for a particular cohort size, we run the model with:
#     - all features
#     - highly correlated features removed
#     - lower importance features removed
#
#     We will be testing cohort sizes = 1000, 2000
#
# - 3. Assess consolidated results
#
#     Choose the feature configuration which produces the best performance. This will be a combination of cohort size, features and unbalanced/rebalanced data.
#
# - 4. Hyperparameter configuration and cross validation
#
#     Having chosen our best feature combination, we will use grid search to identify the best hyper parameters for the model
#
# - 5. Conclusions
# Discussion of results.
#
# Feature importance and random forest ideas from https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 and https://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html#sphx-glr-auto-examples-ensemble-plot-forest-importances-py. We used https://datascienceplus.com/machine-learning-for-diabetes-with-python/ for ideas on how to compare training versus validation for pre and post smote data.
# - Model performance logic was taken from Neural Network coursework previously submitted by Phil Moura

# %%
import pandas as pd
from matplotlib import pyplot as plt
import altair as alt
import seaborn as sns
import statsmodels.api as sm
import scipy.stats as stats
import numpy as np

# %% [markdown]
# ## 1. Load data and identify highly correlated features
#
# ### 1.1 Load socioeconomic and crime dataset

# %%
violence_features_master = pd.read_csv("./DataSources/Income and Deprivation/violence_features_master.csv")
print(violence_features_master.shape)
violence_features_master.head()
# Out:
# (4823, 35)
#    lsoa_code               borough  ldn_datastore_total  police_total  \
# 0  E01000006  Barking and Dagenham                   27          50.0
# 1  E01000007  Barking and Dagenham                  130         188.0
# 2  E01000008  Barking and Dagenham                   23          89.0
# 3  E01000009  Barking and Dagenham                   52         115.0
# 4  E01000010  Barking and Dagenham                  211         430.0
#
#    LSOA Code                  lsoa_name  population  crime_per_1000  \
# 0  E01000006  Barking and Dagenham 016A        2094       12.893983
# 1  E01000007  Barking and Dagenham 015A        2502       51.958433
# 2  E01000008  Barking and Dagenham 015B        1597       14.402004
# 3  E01000009  Barking and Dagenham 016B        1929       26.956973
# 4  E01000010  Barking and Dagenham 015C        3579       58.955015
#
#    crime_per_1000_proportion   lad_code  ... degree_educated_pct  \
# 0                   0.218365  E09000002  ...               0.329
# 1                   0.879936  E09000002  ...               0.323
# 2                   0.243903  E09000002  ...               0.242
# 3                   0.456527  E09000002  ...               0.350
# 4                   0.998426  E09000002  ...               0.449
#
#    population_density  median_house_price  living_environment_rank  \
# 0            0.144255            0.034776                 0.368210
# 1            0.093529            0.010444                 0.386675
# 2            0.100393            0.012705                 0.300409
# 3            0.167821            0.012705                 0.332941
# 4            0.111747            0.013775                 0.078575
#
#    log_rent_social_pct  log_ethnic_other_pct  log_population_density  \
# 0            -3.411248             -3.528124               -1.936171
# 1            -0.898942             -3.905574               -2.369485
# 2            -0.406466             -3.371840               -2.298662
# 3            -1.584745             -3.588608               -1.784857
# 4            -1.343235             -3.408265               -2.191522
#
#    log_median_house_price  log_ethnic_black_pct  log_ethnic_asian_pct
# 0               -3.358826             -2.263997             -0.682052
# 1               -4.561768             -1.274199             -1.135220
# 2               -4.365794             -0.989502             -1.487060
# 3               -4.365794             -2.051083             -0.560744
# 4               -4.284878             -1.588531             -0.857324
#
# [5 rows x 35 columns]

# %% [markdown]
# ### 1.2. Identify highly correlated features
# We don't want the model to overfit on the training data as this will mean it is less able to generalise to unseen data and one method for reducing the level of overfitting is to prune the number of features the model is trained on. We will use two basic approaches for feature pruning, which are to identify variables which highly correlate with other variables and to remove features that are not important for prediction.
#
# It should be noted we only identify features which are candidates for removal. We then later test model performance with and without these candidates being present.
#
# We will do the first of these steps now:

# %%
# extract numeric data
dataset = violence_features_master[['income_deprivation_score',
                                'employment_deprivation_score',
                                'child_income_deprivation_score',
                                'lone_parent_pct',
                                'ethnic_white_pct',
                                'ethnic_mixed_pct',
                                'homeowner_outright_pct',
                                'homeowner_mortgage_pct',
                                'rent_private_pct',
                                'living_environment_rank',
                                'no_qualifications_pct',
                                'degree_educated_pct',
                                'log_rent_social_pct',
                                'log_ethnic_other_pct',
                                'log_population_density',
                                'log_ethnic_black_pct',
                                'log_ethnic_asian_pct',
                                'log_median_house_price']].copy()
                
# derive and plot correlations
corr = dataset.corr()
plt.figure(figsize = (16,16))

ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    annot=True,
    fmt=".2f"
)

# %% [markdown]
# ### Comments
# We can see that income, employment and child income are correlations greater than 0.9 and so we suggest removing 2 of the three from the model. I will therefore test with and without income_deprivation and employment deprivation, while retaining child_income_deprivation in all cases.
#
# ## 2. Perform Random Forest training experiments
# Now we create snapshots based on our 1000, 2000 cohorts and for each we will create an original and rebalanced dataset (using SMOTE). For all datasets we will review feature importance, create predictions, review model performance and then assess our results.
#
# First we create our machine learning functions that we will later use
#
# ### 2.1 Machine learning functions

# %% [markdown]
# #### 2.1.1. Create a dataset with desired cohort size

# %%
def create_snapshot(violence_features_master, cohort_size, feature_list):
    violence_features = violence_features_master.copy()
    
    print("<---- creating dataset with a high crime cohort size = {} ---->".format(cohort_size))
    
    violence_features['high_violence'] = 0
    
    print("shape of violence_features")
    print(violence_features.shape)
    top_n = violence_features.sort_values(by='crime_per_1000', ascending=False)[:cohort_size]
    top_n.high_violence = 1
       
    print("shape of top {} cohort".format(cohort_size))
    print(top_n.shape)
    the_rest = violence_features.sort_values(by='crime_per_1000', ascending=False)[cohort_size:]
    
    print("shape of remaining cohort")
    print(the_rest.shape)

    violence_features_new = top_n.copy()
    violence_features_new = violence_features_new.append(the_rest, ignore_index=True)

    print("shape of recombined cohort")
    print(violence_features_new.shape)

    # just take numeric fields
    dataset = violence_features_new[feature_list].copy()
    
    print("shape of recombined cohort, with just numeric fields")
    print(dataset.shape)
    
    print("<---- dataset with a high crime cohort size = {} created ---->\n".format(cohort_size))
    
    return dataset

# %% [markdown]
# #### 2.1.2 Generate original and rebalanced test and train datasets

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, ADASYN

def get_smote(train_features, train_labels):
    X_resampled, y_resampled = SMOTE().fit_resample(train_features, train_labels)
    
    prior_yes = np.sum(train_labels==1)
    prior_no = np.sum(train_labels==0)
    post_yes =  np.sum(y_resampled==1)
    post_no = np.sum(y_resampled==0)

    labels = ['high crime', 'low crime', 'high crime(SMOTE)', 'low crime (SMOTE)']
    counts = [prior_yes, prior_no, post_yes, post_no]

    plt.figure()
    plt.title('labels before and after rebalancing (SMOTE)')
    plt.bar(labels, counts)
    plt.xticks(labels, rotation=45)
    plt.show()
    
    return X_resampled, y_resampled


def get_test_train_data(dataset):
    # Labels are the values we want to predict
    labels = np.array(dataset['high_violence'])
    # Remove the labels from the features
    # axis 1 refers to the columns
    dataset= dataset.drop('high_violence', axis = 1)
    # Saving feature names for later use
    feature_list = list(dataset.columns)
    # Convert to numpy array
    features = np.array(dataset)
    
    # Split the data into training and testing sets
    train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)
    
    print('Training Features Shape:', train_features.shape)
    print('Training Labels Shape:', train_labels.shape)
    print('Testing Features Shape:', test_features.shape)
    print('Testing Labels Shape:', test_labels.shape)
    
    X_resampled, y_resampled = get_smote(train_features, train_labels)
    
    return train_features, test_features, train_labels, test_labels, X_resampled, y_resampled

# %% [markdown]
# #### 2.1.3. Review feature importance and check model reasonableness

# %%
from sklearn.ensemble import RandomForestClassifier

def feature_importance(rf, data_in):
    
    # remove the label field ('high violence')
    dataset = data_in.copy()
    dataset.drop('high_violence', axis=1, inplace=True)
    
    # Calculate feature importances
    importances = rf.feature_importances_
    # Sort feature importances in descending order
    indices = np.argsort(importances)[::-1]
    
    feature_list = list(dataset.columns)

    # Rearrange feature names so they match the sorted feature importances
    names = [feature_list[i] for i in indices]
    
    # Barplot: Add bars
    plt.bar(range(dataset.shape[1]), importances[indices])
    # Add feature names as x-axis labels
    plt.xticks(range(dataset.shape[1]), names, rotation=90, fontsize = 8)
    # Create plot title
    plt.title("Feature Importance")
    # Show plot
    plt.show()

def model_training(train_features, test_features, train_labels, test_labels):
    
    print("<------ running random forest model ------->\n")
    # Instantiate model with 1000 decision trees
    rf = RandomForestClassifier(n_estimators = 1000, oob_score = True,
                           bootstrap = True, random_state = 42)

    # Train the model on training data
    rf.fit(train_features, train_labels);

        
    print("\n<------ finished running random forest model ------->")
    
    return rf

# %% [markdown]
# #### 2.1.4. Produce and plot model accuracy measures

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve


def RF_performance_reporting(rf, test_features, test_labels, y_pred, description, print_output=True):    
    # I now want to create a confusion matrix and to do this I first have to 
    # change my model output from a probability to a label 1 or 0
   
    accuracy = accuracy_score(test_labels, y_pred)
    precision = precision_score(test_labels, y_pred)
    recall = recall_score(test_labels, y_pred)
    roc_auc = roc_auc_score(test_labels, y_pred)
    cm = confusion_matrix(test_labels, y_pred)
    
    tn, fp, fn, tp = confusion_matrix(test_labels,y_pred).ravel()
    
    if print_output:
        
        print('------------------------------------------------------------------')
        print('Printing performance metrics for ' + description)
        print('------------------------------------------------------------------\n')
        print('prediction accuracy', accuracy)
        print('precision', precision)
        print('recall', recall)
        print('Area under the curve score', roc_auc)   
        print('\n')  

        fpr, tpr, thresholds = roc_curve(test_labels, y_pred)

        plot_confusion_matrix(rf, test_features, test_labels)  
        plt.show() 
        
        metrics.plot_roc_curve(rf, test_features, test_labels)  
        plt.show()
        
    return accuracy, precision, recall, roc_auc, tn, fp, fn, tp

# %% [markdown]
# ### 2.2. Run Model experiments
# Now run the model under a range of conditions in order to deduce the best combination of cohort_size, features and unbalanced vs rebalanced datasets.
#
# First create a dataframe to store our consolidated results

# %%
rf_results_df = pd.DataFrame(columns=['description', 
                                      'accuracy', 
                                      'precision', 
                                      'recall', 
                                      'auc', 
                                      'TP',
                                      'FP',
                                      'TN',
                                      'FN'])

# %% [markdown]
# #### 2.2.1 Option 1: cohort_size = 2000, unbalanced and rebalanced, all features

# %%
# create feature list without income_deprivation and employment_deprivation
feature_list = ['income_deprivation_score',
                'employment_deprivation_score',
                'child_income_deprivation_score',
                'lone_parent_pct',
                'homeowner_outright_pct',
                'homeowner_mortgage_pct',
                'rent_private_pct',
                'no_qualifications_pct',
                'degree_educated_pct',
                'log_rent_social_pct',
                'log_ethnic_other_pct',
                'log_population_density',
                'log_ethnic_black_pct',
                'log_ethnic_asian_pct',
                'log_median_house_price',
                'high_violence']

cohort_size = 2000
dataset = create_snapshot(violence_features_master, cohort_size, feature_list)
train_features, test_features, train_labels, test_labels, X_resampled, y_resampled = get_test_train_data(dataset)

# test with and without SMOTE
rf = model_training(train_features, test_features, train_labels, test_labels)
rf_smote = model_training(X_resampled, test_features, y_resampled, test_labels)

feature_importance(rf, dataset)    
feature_importance(rf_smote, dataset)

# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf, test_features, test_labels, 
                                                                                predictions, 'normal', print_output=True)

rf_result_row = {'description': 'cohort(2000), all features, unbalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)

predictions_smote = rf_smote.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf_smote, 
                                                                                test_features, 
                                                                                test_labels, 
                                                                                predictions_smote, 
                                                                                'SMOTE', print_output=True)

rf_result_row = {'description': 'cohort(2000), all features, rebalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)
# Out:
# <---- creating dataset with a high crime cohort size = 2000 ---->
# shape of violence_features
# (4823, 36)
# shape of top 2000 cohort
# (2000, 36)
# shape of remaining cohort
# (2823, 36)
# shape of recombined cohort
# (4823, 36)
# shape of recombined cohort, with just numeric fields
# (4823, 16)
# <---- dataset with a high crime cohort size = 2000 created ---->
#
# Training Features Shape: (3617, 15)
# Training Labels Shape: (3617,)
# Testing Features Shape: (1206, 15)
# Testing Labels Shape: (1206,)
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# ------------------------------------------------------------------
# Printing performance metrics for normal
# ------------------------------------------------------------------
#
# prediction accuracy 0.7321724709784412
# precision 0.6983805668016194
# recall 0.6647398843930635
# Area under the curve score 0.7239274385575216
# ------------------------------------------------------------------
# Printing performance metrics for SMOTE
# ------------------------------------------------------------------
#
# prediction accuracy 0.7296849087893864
# precision 0.6701940035273368
# recall 0.7321772639691715
# Area under the curve score 0.7299896509074387

# %% [markdown]
# #### Comments
# Recall slightly better with rebalanced but at a slight hit to precision i.e. it over predicts high crime. However AUC and prediction accuracy are very similar and so go with rebalanced
#
# #### 2.2.2 Option 2: cohort_size = 2000, unbalanced, remove income and employment deprivation

# %%
feature_list = ['child_income_deprivation_score',
                'lone_parent_pct',
                'homeowner_outright_pct',
                'homeowner_mortgage_pct',
                'rent_private_pct',
                'no_qualifications_pct',
                'degree_educated_pct',
                'log_rent_social_pct',
                'log_ethnic_other_pct',
                'log_population_density',
                'log_ethnic_black_pct',
                'log_ethnic_asian_pct',
                'log_median_house_price',
                'high_violence']

cohort_size = 2000
dataset = create_snapshot(violence_features_master, cohort_size, feature_list)
train_features, test_features, train_labels, test_labels, X_resampled, y_resampled = get_test_train_data(dataset)

# test with SMOTE only
rf_smote = model_training(X_resampled, test_features, y_resampled, test_labels)
feature_importance(rf_smote, dataset)

predictions_smote = rf_smote.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf_smote, 
                                                                                test_features, 
                                                                                test_labels, 
                                                                                predictions_smote, 
                                                                                'SMOTE', print_output=True)

rf_result_row = {'description': 'cohort(2000), no income|employment deprivation, rebalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)
# Out:
# <---- creating dataset with a high crime cohort size = 2000 ---->
# shape of violence_features
# (4823, 36)
# shape of top 2000 cohort
# (2000, 36)
# shape of remaining cohort
# (2823, 36)
# shape of recombined cohort
# (4823, 36)
# shape of recombined cohort, with just numeric fields
# (4823, 14)
# <---- dataset with a high crime cohort size = 2000 created ---->
#
# Training Features Shape: (3617, 13)
# Training Labels Shape: (3617,)
# Testing Features Shape: (1206, 13)
# Testing Labels Shape: (1206,)
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# ------------------------------------------------------------------
# Printing performance metrics for SMOTE
# ------------------------------------------------------------------
#
# prediction accuracy 0.7271973466003316
# precision 0.6621160409556314
# recall 0.7475915221579962
# Area under the curve score 0.7296909575855484

# %% [markdown]
# #### 2.2.3 Option 3: cohort_size = 2000,rebalanced dataset, extensive feature pruning
# Include income and employment deprivation
# remove
# - log_median_house_price
# - log_ethnic_black_pct
# - degree_educated_pct
# - no_qualifications_pct
# - lone_parent_pct

# %%
feature_list = ['income_deprivation_score',
                'employment_deprivation_score',
                'child_income_deprivation_score',
                'homeowner_outright_pct',
                'homeowner_mortgage_pct',
                'rent_private_pct',
                'log_rent_social_pct',
                'log_ethnic_other_pct',
                'log_population_density',
                'log_ethnic_asian_pct',
                'high_violence']

cohort_size = 2000
dataset = create_snapshot(violence_features_master, cohort_size, feature_list)
train_features, test_features, train_labels, test_labels, X_resampled, y_resampled = get_test_train_data(dataset)

# test with SMOTE only
rf_smote = model_training(X_resampled, test_features, y_resampled, test_labels)
feature_importance(rf_smote, dataset)

predictions_smote = rf_smote.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf_smote, 
                                                                                test_features, 
                                                                                test_labels, 
                                                                                predictions_smote, 
                                                                                'SMOTE', print_output=True)

rf_result_row = {'description': 'cohort(2000), no median_house|ethnic_black|degree|no quals|lone parent, rebalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)
# Out:
# <---- creating dataset with a high crime cohort size = 2000 ---->
# shape of violence_features
# (4823, 36)
# shape of top 2000 cohort
# (2000, 36)
# shape of remaining cohort
# (2823, 36)
# shape of recombined cohort
# (4823, 36)
# shape of recombined cohort, with just numeric fields
# (4823, 11)
# <---- dataset with a high crime cohort size = 2000 created ---->
#
# Training Features Shape: (3617, 10)
# Training Labels Shape: (3617,)
# Testing Features Shape: (1206, 10)
# Testing Labels Shape: (1206,)
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# ------------------------------------------------------------------
# Printing performance metrics for SMOTE
# ------------------------------------------------------------------
#
# prediction accuracy 0.7263681592039801
# precision 0.6620926243567753
# recall 0.74373795761079
# Area under the curve score 0.728491977349791

# %% [markdown]
# #### 2.2.4 Option 4: cohort_size = 2000, rebalanced dataset, minimum feature set
# Remove:
#
# - income_deprivation_score
# - employment_deprivation_score
# - log_median_house_price
# - log_ethnic_black_pct
# - degree_educated_pct
# - no_qualifications_pct
# - lone_parent_pct

# %%
# create feature list without income_deprivation and employment_deprivation
feature_list = ['child_income_deprivation_score',
                'homeowner_outright_pct',
                'homeowner_mortgage_pct',
                'rent_private_pct',
                'log_rent_social_pct',
                'log_ethnic_other_pct',
                'log_population_density',
                'log_ethnic_asian_pct',
                'high_violence']

cohort_size = 2000
dataset = create_snapshot(violence_features_master, cohort_size, feature_list)
train_features, test_features, train_labels, test_labels, X_resampled, y_resampled = get_test_train_data(dataset)

# test with SMOTE only
rf_smote = model_training(X_resampled, test_features, y_resampled, test_labels)
feature_importance(rf_smote, dataset)

predictions_smote = rf_smote.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf_smote, 
                                                                                test_features, 
                                                                                test_labels, 
                                                                                predictions_smote, 
                                                                                'SMOTE', print_output=True)

rf_result_row = {'description': 'cohort(2000), minimum number of features, rebalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)
# Out:
# <---- creating dataset with a high crime cohort size = 2000 ---->
# shape of violence_features
# (4823, 36)
# shape of top 2000 cohort
# (2000, 36)
# shape of remaining cohort
# (2823, 36)
# shape of recombined cohort
# (4823, 36)
# shape of recombined cohort, with just numeric fields
# (4823, 9)
# <---- dataset with a high crime cohort size = 2000 created ---->
#
# Training Features Shape: (3617, 8)
# Training Labels Shape: (3617,)
# Testing Features Shape: (1206, 8)
# Testing Labels Shape: (1206,)
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# ------------------------------------------------------------------
# Printing performance metrics for SMOTE
# ------------------------------------------------------------------
#
# prediction accuracy 0.7197346600331676
# precision 0.6563039723661486
# recall 0.7321772639691715
# Area under the curve score 0.7212560264532902

# %% [markdown]
# #### 2.2.5 Option 5: cohort_size = 1000, unbalanced and rebalanced, all features

# %%
# create feature list without income_deprivation and employment_deprivation
feature_list = ['income_deprivation_score',
                'employment_deprivation_score',
                'child_income_deprivation_score',
                'lone_parent_pct',
                'homeowner_outright_pct',
                'homeowner_mortgage_pct',
                'rent_private_pct',
                'no_qualifications_pct',
                'degree_educated_pct',
                'log_rent_social_pct',
                'log_ethnic_other_pct',
                'log_population_density',
                'log_ethnic_black_pct',
                'log_ethnic_asian_pct',
                'log_median_house_price',
                'high_violence']

cohort_size = 1000
dataset = create_snapshot(violence_features_master, cohort_size, feature_list)
train_features, test_features, train_labels, test_labels, X_resampled, y_resampled = get_test_train_data(dataset)

# test with and without SMOTE
rf = model_training(train_features, test_features, train_labels, test_labels)
rf_smote = model_training(X_resampled, test_features, y_resampled, test_labels)

feature_importance(rf, dataset)    
feature_importance(rf_smote, dataset)

# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf, test_features, test_labels, 
                                                                                predictions, 'normal', print_output=True)

rf_result_row = {'description': 'cohort(1000), all features, unbalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)

predictions_smote = rf_smote.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf_smote, 
                                                                                test_features, 
                                                                                test_labels, 
                                                                                predictions_smote, 
                                                                                'SMOTE', print_output=True)

rf_result_row = {'description': 'cohort(1000), all features, rebalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)
# Out:
# <---- creating dataset with a high crime cohort size = 1000 ---->
# shape of violence_features
# (4823, 36)
# shape of top 1000 cohort
# (1000, 36)
# shape of remaining cohort
# (3823, 36)
# shape of recombined cohort
# (4823, 36)
# shape of recombined cohort, with just numeric fields
# (4823, 16)
# <---- dataset with a high crime cohort size = 1000 created ---->
#
# Training Features Shape: (3617, 15)
# Training Labels Shape: (3617,)
# Testing Features Shape: (1206, 15)
# Testing Labels Shape: (1206,)
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# ------------------------------------------------------------------
# Printing performance metrics for normal
# ------------------------------------------------------------------
#
# prediction accuracy 0.8150912106135987
# precision 0.6864406779661016
# recall 0.30337078651685395
# Area under the curve score 0.6319835828217922
# ------------------------------------------------------------------
# Printing performance metrics for SMOTE
# ------------------------------------------------------------------
#
# prediction accuracy 0.7719734660033167
# precision 0.48757763975155277
# recall 0.5880149812734082
# Area under the curve score 0.7061480657165764

# %% [markdown]
# #### Comments
# Recall is terrible with data that hasn't been rebalanced so only use rebalanced for remaining tests
#
# #### 2.2.6 Option 6: cohort_size = 1000, rebalanced, remove income and employment deprivation

# %%
feature_list = ['child_income_deprivation_score',
                'lone_parent_pct',
                'homeowner_outright_pct',
                'homeowner_mortgage_pct',
                'rent_private_pct',
                'no_qualifications_pct',
                'degree_educated_pct',
                'log_rent_social_pct',
                'log_ethnic_other_pct',
                'log_population_density',
                'log_ethnic_black_pct',
                'log_ethnic_asian_pct',
                'log_median_house_price',
                'high_violence']

cohort_size = 1000
dataset = create_snapshot(violence_features_master, cohort_size, feature_list)
train_features, test_features, train_labels, test_labels, X_resampled, y_resampled = get_test_train_data(dataset)

# test with SMOTE only
rf_smote = model_training(X_resampled, test_features, y_resampled, test_labels)
feature_importance(rf_smote, dataset)

predictions_smote = rf_smote.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf_smote, 
                                                                                test_features, 
                                                                                test_labels, 
                                                                                predictions_smote, 
                                                                                'SMOTE', print_output=True)

rf_result_row = {'description': 'cohort(1000), no income|employment deprivation, rebalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)
# Out:
# <---- creating dataset with a high crime cohort size = 1000 ---->
# shape of violence_features
# (4823, 36)
# shape of top 1000 cohort
# (1000, 36)
# shape of remaining cohort
# (3823, 36)
# shape of recombined cohort
# (4823, 36)
# shape of recombined cohort, with just numeric fields
# (4823, 14)
# <---- dataset with a high crime cohort size = 1000 created ---->
#
# Training Features Shape: (3617, 13)
# Training Labels Shape: (3617,)
# Testing Features Shape: (1206, 13)
# Testing Labels Shape: (1206,)
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# ------------------------------------------------------------------
# Printing performance metrics for SMOTE
# ------------------------------------------------------------------
#
# prediction accuracy 0.7761194029850746
# precision 0.4953271028037383
# recall 0.5955056179775281
# Area under the curve score 0.7114908281580931

# %% [markdown]
# #### 2.2.7. Option 7: cohort_size = 1000, rebalanced dataset, extensive feature pruning
# - include income and employment deprivation
# - remove
#     - log_median_house_price
#     - log_ethnic_black_pct
#     - degree_educated_pct
#     - no_qualifications_pct
#     - lone_parent_pct

# %%
feature_list = ['income_deprivation_score',
                'employment_deprivation_score',
                'child_income_deprivation_score',
                'homeowner_outright_pct',
                'homeowner_mortgage_pct',
                'rent_private_pct',
                'log_rent_social_pct',
                'log_ethnic_other_pct',
                'log_population_density',
                'log_ethnic_asian_pct',
                'high_violence']

cohort_size = 1000
dataset = create_snapshot(violence_features_master, cohort_size, feature_list)
train_features, test_features, train_labels, test_labels, X_resampled, y_resampled = get_test_train_data(dataset)

# test with SMOTE only
rf_smote = model_training(X_resampled, test_features, y_resampled, test_labels)
feature_importance(rf_smote, dataset)

predictions_smote = rf_smote.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf_smote, 
                                                                                test_features, 
                                                                                test_labels, 
                                                                                predictions_smote, 
                                                                                'SMOTE', print_output=True)

rf_result_row = {'description': 'cohort(1000), no median_house|ethnic_black|degree|no quals|lone parent, rebalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)
# Out:
# <---- creating dataset with a high crime cohort size = 1000 ---->
# shape of violence_features
# (4823, 36)
# shape of top 1000 cohort
# (1000, 36)
# shape of remaining cohort
# (3823, 36)
# shape of recombined cohort
# (4823, 36)
# shape of recombined cohort, with just numeric fields
# (4823, 11)
# <---- dataset with a high crime cohort size = 1000 created ---->
#
# Training Features Shape: (3617, 10)
# Training Labels Shape: (3617,)
# Testing Features Shape: (1206, 10)
# Testing Labels Shape: (1206,)
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# ------------------------------------------------------------------
# Printing performance metrics for SMOTE
# ------------------------------------------------------------------
#
# prediction accuracy 0.7669983416252073
# precision 0.4796511627906977
# recall 0.6179775280898876
# Area under the curve score 0.713674600040684

# %% [markdown]
# #### 2.2.8. Option 8: cohort_size = 1000, rebalanced dataset, minimum feature set
# Remove:
# - income_deprivation_score
# - employment_deprivation_score
# - log_median_house_price
# - log_ethnic_black_pct
# - degree_educated_pct
# - no_qualifications_pct
# - lone_parent_pct

# %%
# create feature list without income_deprivation and employment_deprivation
feature_list = ['child_income_deprivation_score',
                'homeowner_outright_pct',
                'homeowner_mortgage_pct',
                'rent_private_pct',
                'log_rent_social_pct',
                'log_ethnic_other_pct',
                'log_population_density',
                'log_ethnic_asian_pct',
                'high_violence']

cohort_size = 1000
dataset = create_snapshot(violence_features_master, cohort_size, feature_list)
train_features, test_features, train_labels, test_labels, X_resampled, y_resampled = get_test_train_data(dataset)

# test with SMOTE only
rf_smote = model_training(X_resampled, test_features, y_resampled, test_labels)
feature_importance(rf_smote, dataset)

predictions_smote = rf_smote.predict(test_features)
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(rf_smote, 
                                                                                test_features, 
                                                                                test_labels, 
                                                                                predictions_smote, 
                                                                                'SMOTE', print_output=True)

rf_result_row = {'description': 'cohort(1000), minimum number of features, rebalanced', 
                 'accuracy': accuracy, 
                 'precision': precision,
                 'recall': recall,
                 'auc': roc_auc, 
                 'TP': tp, 
                 'FP': fp, 
                 'TN': tn, 
                 'FN': fn}

rf_results_df = rf_results_df.append(rf_result_row, ignore_index=True)
# Out:
# <---- creating dataset with a high crime cohort size = 1000 ---->
# shape of violence_features
# (4823, 36)
# shape of top 1000 cohort
# (1000, 36)
# shape of remaining cohort
# (3823, 36)
# shape of recombined cohort
# (4823, 36)
# shape of recombined cohort, with just numeric fields
# (4823, 9)
# <---- dataset with a high crime cohort size = 1000 created ---->
#
# Training Features Shape: (3617, 8)
# Training Labels Shape: (3617,)
# Testing Features Shape: (1206, 8)
# Testing Labels Shape: (1206,)
# <------ running random forest model ------->
#
#
# <------ finished running random forest model ------->
# ------------------------------------------------------------------
# Printing performance metrics for SMOTE
# ------------------------------------------------------------------
#
# prediction accuracy 0.7611940298507462
# precision 0.4700854700854701
# recall 0.6179775280898876
# Area under the curve score 0.7099472304986179

# %% [markdown]
# ## 3. Assess consolidated results
# We now present all results in one place so we can assess which cohort size and feature configuration worked the best

# %%
rf_results_df.sort_values(by='recall', ascending=False)
# Out:
#                                          description  accuracy  precision  \
# 2  cohort(2000), no income|employment deprivation...  0.727197   0.662116
# 3  cohort(2000), no median_house|ethnic_black|deg...  0.726368   0.662093
# 1             cohort(2000), all features, rebalanced  0.729685   0.670194
# 4  cohort(2000), minimum number of features, reba...  0.719735   0.656304
# 0             cohort(2000), all features, unbalanced  0.732172   0.698381
# 8  cohort(1000), no median_house|ethnic_black|deg...  0.766998   0.479651
# 9  cohort(1000), minimum number of features, reba...  0.761194   0.470085
# 7  cohort(1000), no income|employment deprivation...  0.776119   0.495327
# 6             cohort(1000), all features, rebalanced  0.771973   0.487578
# 5             cohort(1000), all features, unbalanced  0.815091   0.686441
#
#      recall       auc   TP   FP   TN   FN
# 2  0.747592  0.729691  388  198  489  131
# 3  0.743738  0.728492  386  197  490  133
# 1  0.732177  0.729990  380  187  500  139
# 4  0.732177  0.721256  380  199  488  139
# 0  0.664740  0.723927  345  149  538  174
# 8  0.617978  0.713675  165  179  760  102
# 9  0.617978  0.709947  165  186  753  102
# 7  0.595506  0.711491  159  162  777  108
# 6  0.588015  0.706148  157  165  774  110
# 5  0.303371  0.631984   81   37  902  186

# %% [markdown]
# ### Conclusions on features
# Experimenting with cohort size of 1000 was interesting but it produced poorer results, particularly when trained without having rebalanced the data. However reblancing gets better recall performance with a small hit to precision and so rebalancing is a good approach.
#
# The feature combination producing best results was all features minus income and employment deprivation (i.e. the ones which correlated highly with child income deprivation)
#
# A recall of 0.74 is reasonable, but this will be slightly inflated because it is over predicting i.e. it produces too many False Positives. But we still go with this because we want to predict high crime. In addition, what is really interesting is that, for our best prediction model, the most important features are:
# - homeowner_mortgage_pct
# - homeowner_outright_pct
# - child_income_deprivation
# - rent_private_pct
# - log_population_density
#
# We believe homeowner and private rent features are important for predicting areas with lower crime, maybe as signifiers for higher wealth and a better living environment, while the deprivation and population density influence whether an area has higher crime, but this is based on our inferential statistics and other analysis rather than the feature importance, because that isn't granular enough to tell us which features have the strongest effect on which label outcomes.
#
# ## 4. Hyperparameter configuration and cross validation
# Having identified which features and cohort size give us the best results, we now want to derive the best random forest model configuration. When assessing our best feature configuration, we created a default model with n_estimators = 1000 and bootstrap = True but now we want to test model performance given different hyperparameter configurations. The configurations we will consider will be as follows (descriptions taken from https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html):
# - bootstrap: Whether bootstrap samples are used when building trees. If False, the whole dataset is used to build each tree.
# - max_depth: If we don't set this then we can get fully grown and unpruned treeswhich can potentially be very large on some data sets. To reduce memory consumption, the complexity and size of the trees should be controlled by setting those parameter values.
# - max_features: The number of features to consider when looking for the best split
# - min_samples_leaf: The minimum number of samples required to be at a leaf node.
# - min_samples_split: The minimum number of samples required to split an internal node
# - n_estimators: number of trees in the forest
#
# We will use a grid search to find the best parameter configuration. We will also use 3 fold cross validation in order to reduce model overfitting.
#
# ### 4.1. First recreate our best dataset (option 9)

# %%
# create feature list without income_deprivation and employment_deprivation
feature_list = ['child_income_deprivation_score',
                'lone_parent_pct',
                'homeowner_outright_pct',
                'homeowner_mortgage_pct',
                'rent_private_pct',
                'no_qualifications_pct',
                'degree_educated_pct',
                'log_rent_social_pct',
                'log_ethnic_other_pct',
                'log_population_density',
                'log_ethnic_black_pct',
                'log_ethnic_asian_pct',
                'log_median_house_price',
                'high_violence']

cohort_size = 2000
dataset = create_snapshot(violence_features_master, cohort_size, feature_list)
train_features, test_features, train_labels, test_labels, X_resampled, y_resampled = get_test_train_data(dataset)
# Out:
# <---- creating dataset with a high crime cohort size = 2000 ---->
# shape of violence_features
# (4823, 36)
# shape of top 2000 cohort
# (2000, 36)
# shape of remaining cohort
# (2823, 36)
# shape of recombined cohort
# (4823, 36)
# shape of recombined cohort, with just numeric fields
# (4823, 14)
# <---- dataset with a high crime cohort size = 2000 created ---->
#
# Training Features Shape: (3617, 13)
# Training Labels Shape: (3617,)
# Testing Features Shape: (1206, 13)
# Testing Labels Shape: (1206,)

# %% [markdown]
# ### 4.2. Perform Grid Search to identify best model configuration
# Create a grid of potential values for each hyperparameter and use a grid search to choose combinations with which to train the model. Incorporate 3 fold cross validation to reduce overfitting.

# %%
import time
from sklearn.model_selection import GridSearchCV

param_grid = {
    'bootstrap': [True],
    'max_depth': [2, 3, 5],
    'max_features': [3, 4],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [500, 1000, 2000]
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
gs_rf = GridSearchCV(estimator = rf, param_grid = param_grid, refit=True,
                          cv = 3, n_jobs = -1, verbose = 2)

tic = time.perf_counter()
gs_rf.fit(X_resampled, y_resampled)
toc = time.perf_counter()

print(f"Running the Random Forest classifer on our best features dataset took {toc - tic:0.4f} seconds")
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# Running the Random Forest classifer on our best features dataset took 281.4711 seconds

# %% [markdown]
# ### 4.3. Assess performance of tuned model
# We used refit=True which means the GridSearch returns the best model already trained

# %%
y_pred = gs_rf.predict(test_features)

# %%
accuracy, precision, recall, roc_auc, tn, fp, fn, tp = RF_performance_reporting(gs_rf, 
                                                                                test_features, 
                                                                                test_labels, 
                                                                                y_pred, 
                                                                                'optimal model', 
                                                                                print_output=True)
# Out:
# ------------------------------------------------------------------
# Printing performance metrics for optimal model
# ------------------------------------------------------------------
#
# prediction accuracy 0.7114427860696517
# precision 0.6350710900473934
# recall 0.7745664739884393
# Area under the curve score 0.7191609662518615

# %% [markdown]
# ### Comments
# The recall is good, because it means that the model predicts a high crime area 77% of the time. However, the downside is the model is too quick to predict a high crime area, because it will falsely predict a high crime area 33% of the time. This means that it's a toss up between this optimised model and Option 2 model, which had a better precision. In both cases however, the model does have moderate predictive power as evidenced by an AUC score of above 0.72.
#
# The final step is to check which are the most important features in this final model to see whether they are the same as in Option 2
# - we need to recreat the model using the best parameters because our features_importance function doesn't work with a cross validated model returned by a grid search

# %%
gs_rf.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 5,
#  'max_features': 4,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8,
#  'n_estimators': 500}

# %%
rf_final = RandomForestClassifier(n_estimators = 500, oob_score = True,
                           bootstrap = True, random_state = 42, max_depth=5, 
                           max_features=4, min_samples_leaf=3, min_samples_split=8)

# Train the model on training data
rf_final.fit(X_resampled, y_resampled)

feature_importance(rf_final, dataset)

# %% [markdown]
# ## 5. Conclusions
# We can produce a reasonable predictor for areas with high serious violent crime and the most important features for these best predictors are:
# - homeownership levels
# - child deprivation
# - the proportion of private rental
# - log(social rent)
# - log(population density)
#
# Which are interesting when compared to the spearman correlations we calculated previously (except for private rental).
#
# We believe homeowner and private rent features are important for predicting areas with lower crime, maybe as signifiers for higher wealth and a better living environment, while the deprivation and population density influence whether an area has higher crime, but this is based on our inferential statistics and other analysis rather than the feature importance, because that isn't granular enough to tell us which features have the strongest effect on which label outcomes.

# %% [markdown]
# <img src="spearman_correlations.png">
