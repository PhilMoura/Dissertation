# %% [markdown]
# # This is tempy mctempface

# %%
import datetime
import pandas as pd
import numpy as np

# %%
all_tweets = pd.read_csv("./DataSources/TwitterData/cleaned_tweets_20210806.csv")
print(all_tweets.shape)
all_tweets.head()
# Out:
# (24772, 25)
#    index             tweet_id           tweet_date           tweeter_id  \
# 0      0  1420355029081395203  2021-07-28 12:06:42   865262041103302656
# 1      1  1420354120041615364  2021-07-28 12:03:05            229645453
# 2      2  1420351785156366337  2021-07-28 11:53:49           2843896642
# 3      3  1420350419449094148  2021-07-28 11:48:23            556315551
# 4      4  1420349615954669574  2021-07-28 11:45:11  1267062754915090434
#
#   tweeter_user_name tweeter_screen_name            tweeter_location  \
# 0       Chris Myers     myerschrismyer1    Richmond North Yorkshire
# 1   Emily Sheffield      emilysheffield                      London
# 2       Basilewitch         basilewitch                      France
# 3      Dean Cowcher         DeanCowcher  Bexleyheath London England
# 4          Alfiecat         sonya_annie                     unknown
#
#                                         message_text  \
# 0  RT @LeslieH24367191: 'Do better!' Boris Johnso...
# 1  RT @NaheedMajeed: Spot on @standardnews With L...
# 2  RT @Short2Cjs: Boris today speaking to Nick Fe...
# 3  RT @LeslieH24367191: 'Do better!' Boris Johnso...
# 4  RT @Short2Cjs: Boris today speaking to Nick Fe...
#
#   in_reply_to_user_screen_name quote_tweet_screen_name  ...  \
# 0                          NaN                     NaN  ...
# 1                          NaN                     NaN  ...
# 2                          NaN                     NaN  ...
# 3                          NaN                     NaN  ...
# 4                          NaN                     NaN  ...
#
#            mentioned  hashtags  \
# 0                 []        []
# 1  ['@standardnews']        []
# 2                 []        []
# 3                 []        []
# 4                 []        []
#
#                                          Tweet_punct  \
# 0   Do better Boris Johnson issues scathing respo...
# 1   Spot on  With London on track to break record...
# 2   Boris today speaking to Nick Ferrari about Kh...
# 3   Do better Boris Johnson issues scathing respo...
# 4   Boris today speaking to Nick Ferrari about Kh...
#
#                                      Tweet_tokenized  \
# 0  ['do', 'better', 'boris', 'johnson', 'issues',...
# 1  ['spot', 'on', 'with', 'london', 'on', 'track'...
# 2  ['boris', 'today', 'speaking', 'to', 'nick', '...
# 3  ['do', 'better', 'boris', 'johnson', 'issues',...
# 4  ['boris', 'today', 'speaking', 'to', 'nick', '...
#
#                                        Tweet_nonstop  \
# 0  ['better', 'boris', 'johnson', 'issues', 'scat...
# 1  ['spot', 'track', 'break', 'record', 'teenage'...
# 2  ['boris', 'today', 'speaking', 'nick', 'ferrar...
# 3  ['better', 'boris', 'johnson', 'issues', 'scat...
# 4  ['boris', 'today', 'speaking', 'nick', 'ferrar...
#
#                                     Tweet_lemmatized  \
# 0  ['good', 'boris', 'johnson', 'issues', 'scathi...
# 1  ['spot', 'track', 'break', 'record', 'teenage'...
# 2  ['boris', 'today', 'speaking', 'nick', 'ferrar...
# 3  ['good', 'boris', 'johnson', 'issues', 'scathi...
# 4  ['boris', 'today', 'speaking', 'nick', 'ferrar...
#
#                                    Clean_MessageText        tweet_date_dt  \
# 0  good boris johnson issues scathing response sa...  2021-07-28 12:06:42
# 1  spot track break record teenage murdersstop se...  2021-07-28 12:03:05
# 2  boris today speaking nick ferrari khan … done ...  2021-07-28 11:53:49
# 3  good boris johnson issues scathing response sa...  2021-07-28 11:48:23
# 4  boris today speaking nick ferrari khan … done ...  2021-07-28 11:45:11
#
#          time_bins_12h day_bins
# 0  2021-07-28 12:00:00       28
# 1  2021-07-28 12:00:00       28
# 2  2021-07-28 00:00:00       28
# 3  2021-07-28 00:00:00       28
# 4  2021-07-28 00:00:00       28
#
# [5 rows x 25 columns]

# %%
all_tweets = all_tweets.dropna(how='all') # only drops a row when every column is NA
print("shape before after dropping rows with all NaN")
print(all_tweets.shape)

# Now check for individual NaN values
nan_values = all_tweets[all_tweets.isna().any(axis=1)]
print(nan_values.count())
# Out:
# shape before after dropping rows with all NaN
# (24772, 25)
# index                           24741
# tweet_id                        24741
# tweet_date                      24741
# tweeter_id                      24741
# tweeter_user_name               24741
# tweeter_screen_name             24741
# tweeter_location                24741
# message_text                    24741
# in_reply_to_user_screen_name     2608
# quote_tweet_screen_name           425
# favourite_count                 24741
# retweet_count                   24741
# extract_run_date                24741
# retrieved_using_search_term     24741
# retweeted                       24741
# mentioned                       24741
# hashtags                        24741
# Tweet_punct                     24741
# Tweet_tokenized                 24741
# Tweet_nonstop                   24741
# Tweet_lemmatized                24741
# Clean_MessageText               24739
# tweet_date_dt                   24741
# time_bins_12h                   24741
# day_bins                        24741
# dtype: int64

# %%
# need to set the in_reply_to_user_screen_name and quote_tweet_screen_name fields to blanks
all_tweets.loc[all_tweets['in_reply_to_user_screen_name'].isna(), 'in_reply_to_user_screen_name'] = ''
all_tweets.loc[all_tweets['quote_tweet_screen_name'].isna(), 'quote_tweet_screen_name'] = ''

# Now check for individual NaN values
nan_values = all_tweets[all_tweets.isna().any(axis=1)]
print(nan_values.count())

nan_values.head()
# Out:
# index                           2
# tweet_id                        2
# tweet_date                      2
# tweeter_id                      2
# tweeter_user_name               2
# tweeter_screen_name             2
# tweeter_location                2
# message_text                    2
# in_reply_to_user_screen_name    2
# quote_tweet_screen_name         2
# favourite_count                 2
# retweet_count                   2
# extract_run_date                2
# retrieved_using_search_term     2
# retweeted                       2
# mentioned                       2
# hashtags                        2
# Tweet_punct                     2
# Tweet_tokenized                 2
# Tweet_nonstop                   2
# Tweet_lemmatized                2
# Clean_MessageText               0
# tweet_date_dt                   2
# time_bins_12h                   2
# day_bins                        2
# dtype: int64
#        index             tweet_id           tweet_date           tweeter_id  \
# 6085    6085  1417805178540105730  2021-07-21 11:14:30  1397801811935956993
# 17157  17157  1421529556121489410  2021-07-31 17:53:51            279478380
#
#       tweeter_user_name tweeter_screen_name tweeter_location  \
# 6085              Jimmy       Jimmy20723610     Mother Earth
# 17157         Artur.Kli           ArturK_IE          Ireland
#
#                                             message_text  \
# 6085   @BraddockBessie https://t.co/23Cde1u6r3\nhttps...
# 17157  @forwardnotbac @MayorofLondon Sure is https://...
#
#       in_reply_to_user_screen_name quote_tweet_screen_name  ...  \
# 6085                BraddockBessie                          ...
# 17157                forwardnotbac                          ...
#
#                                   mentioned  hashtags  Tweet_punct  \
# 6085                    ['@BraddockBessie']        []      \n\n\n
# 17157  ['@forwardnotbac', '@MayorofLondon']        []     Sure is
#
#       Tweet_tokenized Tweet_nonstop Tweet_lemmatized Clean_MessageText  \
# 6085               []            []               []               NaN
# 17157  ['sure', 'is']            []               []               NaN
#
#              tweet_date_dt        time_bins_12h day_bins
# 6085   2021-07-21 11:14:30  2021-07-21 00:00:00       21
# 17157  2021-07-31 17:53:51  2021-07-31 12:00:00       31
#
# [2 rows x 25 columns]

# %% [markdown]
# ## Building the network of interactions
# ### This code draws heavily on the work of Bovet
# ### https://github.com/alexbovet/network_lesson/blob/master/02_Analysis_of_Twitter_Social_Network.ipynb
#
# We will use the python module NetworkX to construct and analyze the social network.
#
# There are four types of interactions between two users in Twitter:
# - Retweet
# - Quote
# - Reply
# - Mention

# %%
# let's define some functions to extract the interactions from tweets
def string_to_list(my_str):
    delimiter = ","
    my_str = my_str.replace("[", "")
    my_str = my_str.replace("]", "")
    my_str = my_str.replace("@", "")
    my_str = my_str.replace("'", "")
    my_str = my_str.replace(" ", "")
    my_list = my_str.split(delimiter)
    return my_list

def getAllInteractions(tweet):
    
    # Get the tweeter
    tweet_id = tweet.tweet_id
    tweeter_id = tweet.tweeter_id
    tweeter_name = tweet.tweeter_screen_name
    
    # a python set is a collection of unique items
    # we use a set to avoid duplicated ids
    interacting_users = set()
    
    # Add person they're replying to
    if tweet.in_reply_to_user_screen_name != '':
        interacting_users.add(tweet.in_reply_to_user_screen_name)
        
    # Add person they quoted
    if tweet.quote_tweet_screen_name != '':
        interacting_users.add(tweet.quote_tweet_screen_name)
    
    # Add person they retweeted
    if len(tweet.retweeted) > 2: # because empty strings will contain []
        retweeted_list = string_to_list(tweet.retweeted)
        for item in retweeted_list:
            interacting_users.add(item)
       
    # Add mentions
    if len(tweet.mentioned) > 2: # because empty strings will contain []
        mentioned_list = string_to_list(tweet.mentioned)
        for item in mentioned_list:
            interacting_users.add(item)
  
    # remove the tweeter if he is in the set
    interacting_users.discard(tweeter_name)
    
    # Return our tweeter and their influencers
    return tweeter_id, tweeter_name, tweet_id, list(interacting_users)

# %%
import networkx as nx

# define an empty Directed Graph
# A directed graph is a graph where edges have a direction
# in our case the edges goes from user that sent the tweet to
# the user with whom they interacted (retweeted, mentioned or quoted)
G = nx.DiGraph()

for index, tweet in all_tweets.iterrows():
    
    if (tweet.tweeter_screen_name != 'SadiqKhan') & (tweet.tweeter_screen_name != 'MayorofLondon'):
        tweeter_id, tweeter_name, tweet_id, interactions = getAllInteractions(tweet)
    
        # add an edge to the Graph for each influencer
        for interact_name in interactions:
        
            # add edges between the two user ids
            # this will create new nodes if the nodes are not already in the network
            # we also add an attribute the to edge equal to the id of the tweet
            G.add_edge(tweeter_name, interact_name, tweet_id=tweet_id)
        
            # add name as a property to each node
            # with networkX each node is a dictionary
            G.nodes[tweeter_name]['name'] = tweeter_name
            G.nodes[interact_name]['name'] = interact_name

# %% [markdown]
# ## Start with network characteristics
# Based on tutorial from: https://programminghistorian.org/en/lessons/exploring-and-analyzing-network-data-with-python

# %%
print(nx.info(G))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 17220
# Number of edges: 25947
# Average in degree:   1.5068
# Average out degree:   1.5068

# %%
# On a scale of 0 to 1, where 1 is a dense network
density = nx.density(G)
print("Network density:", density)
# Out:
# Network density: 8.750766159980882e-05

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# %%
degree_dict
# Out:
# {'myerschrismyer1': 3,
#  'LeslieH24367191': 573,
#  'emilysheffield': 24,
#  'NaheedMajeed': 6,
#  'standardnews': 302,
#  'basilewitch': 11,
#  'Short2Cjs': 9,
#  'DeanCowcher': 8,
#  'sonya_annie': 3,
#  'OliverSteinme16': 4,
#  'Kalimeralynn': 4,
#  'Bravescott69': 3,
#  'GM_RayKeene': 2,
#  'Howwee': 7,
#  'bramble__jam': 1,
#  'UncleTrash': 2,
#  'Sheilamayparke1': 3,
#  'boblister_poole': 72,
#  'John27454952': 5,
#  'linmeitalks': 11,
#  'darlingvivien': 8,
#  'becky10002': 1,
#  'LBC': 261,
#  'JoRichardsKent': 3,
#  'Nic': 2,
#  'NickFerrariLBC': 55,
#  'RosettaTickner': 6,
#  'Janet42957897': 7,
#  'KarlJiAllen': 8,
#  'neerajsanatani1': 1,
#  'LeoKearse': 635,
#  'Morris2906': 10,
#  '527_thatch': 1,
#  'SadiqKhan': 796,
#  'philrevis': 1,
#  'Susanmerryweath': 2,
#  'parthkopi': 1,
#  'Alfiebengal': 1,
#  'Mal_DuBois': 6,
#  'moore241128': 2,
#  'JuliaHB1': 29,
#  'Bigjob67643000': 1,
#  'lindiloola': 2,
#  'tamdek': 1,
#  'FrankBullitt39': 5,
#  'PAL362': 13,
#  'AlisonAjt': 1,
#  'Keir_Starmer': 140,
#  'DavidNerd': 1,
#  'Alwof': 1,
#  'thegingerpig': 21,
#  'LizardEyeSue': 5,
#  'CandyNimrod': 8,
#  'RockerProg': 4,
#  'Shakermakermatt': 2,
#  'Peter86628983': 7,
#  'ianbeach2': 1,
#  'AmuAlan': 3,
#  'GillJames54': 17,
#  'Archer64234817': 3,
#  'Conservatives': 19,
#  'AnnaBritannia': 3,
#  'antiwokeuk': 46,
#  'porknpicklepie': 15,
#  'trwill10_tom': 5,
#  'DnellStephen': 12,
#  'BeccaHutson': 1,
#  'GBNEWS': 349,
#  'BikerGary17': 4,
#  'elibo_17': 9,
#  'Dredekia': 2,
#  'aAw6WFLEArS9hVL': 4,
#  'Baconsarni1': 6,
#  'kevin0u': 3,
#  'SusanHu25307477': 9,
#  'pramod_abhms': 1,
#  'lizshep73': 2,
#  'anandsharma333': 1,
#  'froghound01': 1,
#  'AlfieTurner2': 11,
#  'brianpaddick': 15,
#  'EnglishBob7777': 1,
#  'plddly': 5,
#  'thebarkingtweet': 3,
#  'lifeisgoodtake2': 1,
#  'mrhazzers': 1,
#  'James_Thorburn': 858,
#  'andrewamg': 5,
#  'marsman1258': 3,
#  'd5_rss': 6,
#  'AtlasB2B': 8,
#  'a_shipl12': 5,
#  'Peter_Clark8': 14,
#  'heliman_david': 10,
#  'thepoohs15': 2,
#  'talkRADIO': 263,
#  'PatrickChristys': 17,
#  'soozywooozy': 2,
#  'Lozzerdude': 2,
#  'UKLabour': 43,
#  'Sigbertganser': 1,
#  'bywirenews': 1,
#  'gplondon': 2,
#  'metpoliceuk': 246,
#  'heather_venter': 1,
#  'ChristinaDonn11': 10,
#  'AndyWells7': 9,
#  'DavidHawker17': 3,
#  'slightlymad1': 3,
#  'bigD17952310': 5,
#  'PolygonHouse': 3,
#  'markrmayhew': 1,
#  'Daily_Express': 38,
#  'smeemartin': 2,
#  'ray_walker4': 2,
#  'ROmuyaaye': 1,
#  'Q3j1u9haIfEACRd': 1,
#  'Carla_littlerob': 3,
#  'AndrewGoldthor3': 3,
#  '2ndWinston': 4,
#  'DavidLammy': 35,
#  'James2Squ4': 1,
#  'martinlewis74': 2,
#  'AlexFerguson50': 10,
#  'FourAdamThirty': 5,
#  'Jamie_Harte71': 3,
#  'burnssl': 5,
#  'darrenhunter2': 1,
#  'JackieChild2': 1,
#  'LBCNews': 29,
#  'jonatha36469630': 6,
#  'jodie05625116': 2,
#  'LegTeddys': 1,
#  'mattrhucs': 1,
#  'Gauci10P': 3,
#  'viewsfromleft': 9,
#  'SuzaEnver': 2,
#  'marionste': 4,
#  'shivanisharmaaa': 1,
#  'sirose79': 37,
#  'WhitstableStev1': 10,
#  'scoutnick': 3,
#  'Webbo2306': 2,
#  'MayorofLondon': 556,
#  'DalbyTerrance': 3,
#  'mayavikrushna': 1,
#  'Abqaic70': 1,
#  'mrjamesob': 24,
#  'SolitudeDude1': 1,
#  'EdwardLeftEU': 1,
#  'moganney': 1,
#  'makeshkumardur2': 1,
#  'PathakMitra': 1,
#  'DharmaCalling': 1,
#  'AnkitSh51773951': 1,
#  'yogirajshakya': 1,
#  'AmitabhPoddar1': 1,
#  'Vijay40612217': 1,
#  'BabbarKamal': 1,
#  'SanjayK19921599': 1,
#  'TheAllseen': 1,
#  'Kishore36414788': 1,
#  'shaandilya_': 1,
#  'Indic_e': 1,
#  'abhirj87': 1,
#  'harish3912': 1,
#  'SurenderKD29': 1,
#  'snobfielder': 1,
#  'Archana071114': 1,
#  'astik_shishya': 1,
#  'Ladaku_Viman': 1,
#  'MukulAgarwal66': 1,
#  'sagarManOfSteel': 1,
#  'nbhardwaj2009': 1,
#  'Shraddhayoga14': 1,
#  'WatchfulGaruda': 1,
#  'RanjiniTam': 1,
#  'mea_gulpa': 1,
#  'dhakad135636': 1,
#  'raghuttam88': 1,
#  'HariomS20741285': 1,
#  'Khemchandjoya': 1,
#  'satyaanaveshi': 1,
#  'BKyxZaBYqKwPaPv': 1,
#  'MRITUNJAY1977': 1,
#  'jagannath': 1,
#  'Hichmalumnist': 1,
#  'niruveer': 1,
#  'ravalnaresh772': 1,
#  'jsavandhi': 1,
#  'Being_Pagan': 1,
#  'rajca2011': 1,
#  'bruceyboylondon': 2,
#  'PaulCasella2': 4,
#  'maryram70722202': 1,
#  'Tarun33864349': 1,
#  'milkgapes': 1,
#  'inthesedeserts': 2,
#  'Vignesh90295553': 1,
#  'Juliejoolsw': 1,
#  'Cypher79C': 2,
#  'chrissy_demo': 3,
#  'YoloYadav': 1,
#  'col_jed': 1,
#  'fosterite': 1,
#  'davidschneider': 2,
#  'giddey_srikanth': 1,
#  'PatWilliams1944': 9,
#  'Senag23': 1,
#  'gordontag1': 9,
#  'scarycath': 1,
#  'tartannettles13': 1,
#  'david_LondonW5': 3,
#  'suemitch2017': 94,
#  'sreevatson': 1,
#  'ben_mw': 1,
#  'Turfline': 6,
#  'EstaSnide': 2,
#  'orr_it': 1,
#  'Carona2004': 3,
#  'pamela03702219': 2,
#  'PCisfinished': 17,
#  'BillBillBill06': 1,
#  'unassailable': 1,
#  'BhaveshSBL': 1,
#  'Manmoha11080158': 1,
#  'RajeevKSachan': 1,
#  'Adam33936324': 1,
#  'RobertMadeley01': 15,
#  'jamesst16366799': 4,
#  'GraemeSBradley1': 1,
#  'Gailslinn': 5,
#  'Timelord420': 1,
#  'patrickolajide': 4,
#  'PFEW_Chair': 1,
#  'kevinduffy999': 1,
#  'eddiemair': 1,
#  '_gupta_mohit_': 1,
#  'chetanrajchauh1': 3,
#  'MartinCainActon': 3,
#  'Sa': 23,
#  'Paurushya': 1,
#  'IIMNationalists': 1,
#  'sebcollective1': 3,
#  'iancollinsuk': 4,
#  'tkmagesh': 1,
#  'Ramani58942841': 1,
#  'FollowThyLead': 1,
#  'AIM_IJ': 6,
#  'mickygees': 1,
#  'paiyabalajijn': 1,
#  'arvajaa': 1,
#  'NexgenWellbeing': 2,
#  'escobarexports': 7,
#  'dvinesndwchmakr': 1,
#  'Devi_Uvacha': 1,
#  'marls16422440': 1,
#  'rameshbobbu': 1,
#  'kamalpd': 1,
#  'GPakoda': 1,
#  'rama_bhakt': 1,
#  'NaomiLWood': 1,
#  'anuragrby1': 1,
#  'NitinSh02657621': 1,
#  'nutsnvoltz': 1,
#  'SAnsumali': 1,
#  'Lalit_maurya1': 1,
#  'GOKU184507': 1,
#  'cinnamon201718': 4,
#  'PRIYANS26884918': 1,
#  'vismayshah': 1,
#  'Alchemist932': 1,
#  'kumaoni_woman': 1,
#  'SamVisa41': 1,
#  '83_saudagar': 1,
#  'NissarGuru': 1,
#  'manjula_induku1': 1,
#  'vikrams17068903': 1,
#  'bhanuvachan': 1,
#  '1420kunal': 1,
#  'simonjcrosland': 1,
#  'PhilWilliams': 1,
#  'philipjdoyle': 10,
#  'LBR_Ripoff_Scam': 3,
#  'byasadev_mishra': 1,
#  'sandeeparya4u': 1,
#  'NegiSannie': 1,
#  'DenierLockdown': 7,
#  'callnum1': 2,
#  'imNishant77': 1,
#  'Neerajhit619': 1,
#  'MartinG8177': 4,
#  'MPFed': 29,
#  'Samarth80204902': 1,
#  '27476b54549e462': 1,
#  'essvee19': 1,
#  'cuceritorallumi': 1,
#  'DhartiPutra1234': 1,
#  'dorian_smith': 3,
#  'bestofbritish2': 1,
#  'WingHelping': 1,
#  'I_Lucky_56': 1,
#  'HelenYates52': 6,
#  'PoliceInspForum': 9,
#  'aaronub4t': 1,
#  'MichelleDewbs': 4,
#  'wfrost96': 1,
#  'ConservativeHSP': 1,
#  'MAYURBHOSLE14': 1,
#  'Archieb48709437': 3,
#  'abhishereporter': 1,
#  'Black_Author': 10,
#  'OliverOrnets': 1,
#  'colinelves': 1,
#  'libransoul03': 1,
#  'bhandari_saab_': 1,
#  'JGerrings': 1,
#  'davealexbrexit': 2,
#  'jthraves23': 1,
#  'b1570c7168eb48b': 1,
#  'lucyann28211055': 2,
#  'FCARA_Bow': 1,
#  'BurdettFC': 5,
#  'Pargaras': 1,
#  'janjay_j': 5,
#  'jambos81': 3,
#  'officialbarnesy': 2,
#  'MikeTaiwan2': 1,
#  'akalamusic': 1,
#  'moistmallow': 2,
#  'mightbevinny': 1,
#  'mousemallow__': 1,
#  'nodbear': 4,
#  'SellickJohn': 3,
#  'andytomlins': 1,
#  'gibraltarfx': 1,
#  'MaireidUi': 2,
#  'robbo32': 1,
#  'Petchelli': 1,
#  'philashton68': 1,
#  'BBCNews': 107,
#  'jdjack1': 5,
#  'peterro70652951': 3,
#  'bfchild66': 1,
#  'WestBelfastUPRG': 1,
#  'slicedalone': 3,
#  'JeremyCordite': 2,
#  'Melissa5857': 4,
#  'BorisJohnson': 139,
#  'oldtoonloon': 7,
#  'dksheff': 1,
#  'Englishgentlem9': 4,
#  'kelvmackenzie': 1,
#  'davewomble': 6,
#  'TfL': 43,
#  'BlackScarfMarc': 1,
#  'richmoody8': 1,
#  'themoreyoupush': 3,
#  'Aetius77': 6,
#  'PantsBaggy': 1,
#  'ScotCampbell9': 1,
#  'jonatanpallesen': 1,
#  'thegigginhman': 1,
#  'RAVerBruggen': 1,
#  'icecreamconean': 1,
#  'RockyWasYer': 5,
#  'andy_baptiste': 2,
#  'mollskb_': 5,
#  'Herewar66545077': 4,
#  'paulJpitt1967': 8,
#  'Katrina20932914': 3,
#  'deephouse44': 3,
#  'Iromg': 22,
#  'blackvanman1': 1,
#  'roger_lfc': 3,
#  'UkPolitoons': 5,
#  'parentchain': 6,
#  'DeptfordRising': 1,
#  'eddiecoke': 7,
#  'mrichie10': 8,
#  'SkyNews': 23,
#  'WhitsJnr': 3,
#  'CCBK666': 3,
#  'AndrewCastell2': 3,
#  'AngelaRayner': 9,
#  'andystubbington': 3,
#  'HistoryUnchain': 1,
#  'Grayruskin': 1,
#  'Kingkongsfinge3': 2,
#  'itvnews': 25,
#  'InkandAmber1': 7,
#  'marthapick3': 1,
#  'chris3103861': 1,
#  'nny_grin': 1,
#  'riwired': 4,
#  'rockmeamadeus6': 1,
#  'inthezoneuk': 1,
#  'MaajidNawaz': 5,
#  'Patrici73361599': 1,
#  'DianaFire': 2,
#  'fullvax4freedo1': 2,
#  'TowerHamletsNow': 2,
#  'SamTheologetics': 1,
#  'ATVG2k20': 1,
#  'RavinderKITaylo': 2,
#  'MarjaCampbell2': 1,
#  'NiallFraser8': 1,
#  'twose_brian': 7,
#  'PoliticsForAlI': 294,
#  '19531066B': 7,
#  'gardenplants3': 5,
#  'carolinesteel1': 5,
#  'JKBOY92': 1,
#  'CG7268': 5,
#  'mfc815': 8,
#  'anti_woke_': 1,
#  'MikeGeolHorton': 2,
#  'docrussjackson': 9,
#  'spectator': 14,
#  'JimCoulter15': 2,
#  'ComGymBro': 3,
#  'Mikey82301527': 2,
#  'joanna202020': 1,
#  'CoreySherrif': 2,
#  'MagsAssoc': 1,
#  'netpol': 15,
#  'JohnNeophytou': 4,
#  'IanMcDo68808105': 1,
#  'kieran26272': 1,
#  'RealBertRogers': 3,
#  'KebabGazz': 3,
#  'DavidRickelton': 4,
#  'leearmstrong28': 1,
#  'james_0676': 3,
#  'UzuNeymar': 3,
#  'bearpittelder': 10,
#  'TheAminur11': 1,
#  'swishfast': 4,
#  'jackyant': 2,
#  'chas1937': 2,
#  'willybobs48': 1,
#  'Godfrey28482926': 11,
#  'GBNfans': 37,
#  '21in2022': 3,
#  'PeggyFagan45': 3,
#  'MinsterOfDiver1': 2,
#  'Channel4News': 4,
#  'TheatreTwittic': 1,
#  'monktresor': 1,
#  'PriorConstruct': 1,
#  'Chris_short1991': 1,
#  'NewsForAllUK': 40,
#  'DavidMcKeever8': 3,
#  'andshoal': 3,
#  'bmay': 4,
#  'johncoxonmedia': 3,
#  'curiocat13': 6,
#  'DKruku': 3,
#  'TheDayItChanged': 1,
#  'NormanMurison1': 2,
#  'Stephen97929888': 8,
#  'ToddSharpville': 1,
#  'Finkley1': 4,
#  'Robee_Darkhalf': 3,
#  'LloydGeorge57': 3,
#  'aarondhealey': 2,
#  'citysoul5': 2,
#  'traxdevos': 1,
#  'barrylcthompson': 3,
#  'sumile52852444': 1,
#  'GrimReaper1960': 18,
#  'Grantmpayne_Jac': 1,
#  'ItsAllDust': 1,
#  'freddie2284': 4,
#  'MZ05_': 2,
#  'Weescot4': 1,
#  'TomMillerUK': 1,
#  'Brent_Council': 1,
#  'bharatvarsh_1': 3,
#  'zombiek92015586': 2,
#  'lsrlinda': 4,
#  'plugster01': 3,
#  'guardian': 14,
#  'Lesley_London': 5,
#  'Joanna__Hardy': 2,
#  'chrishill87': 2,
#  'Lagertha763AD': 1,
#  'dalunz': 1,
#  'Smdge13': 1,
#  'Kent_Online': 3,
#  'joanwri16980637': 4,
#  'CryptoG71': 2,
#  'ToadSag17193450': 2,
#  'Sozzinski': 4,
#  'London_Coomber': 1,
#  'anonawins': 1,
#  'Michael16229595': 2,
#  'whendemocracy': 1,
#  'Richlin11a': 8,
#  'GeorgeSoreArse': 1,
#  'richardwilson68': 6,
#  'dl9255': 6,
#  'DDawn0': 11,
#  'ExecutiveWheat': 1,
#  'ComleyRitchie': 3,
#  'AJMattis': 1,
#  'thetimes': 7,
#  'minx8888': 1,
#  'Mc_Lote': 1,
#  'pipermajor': 3,
#  'SueMortimer18': 2,
#  'Captain20359212': 1,
#  'Ramesh13145522': 1,
#  'wardj15': 15,
#  'PetenShirl': 10,
#  'shirley738213': 7,
#  'MutzUk': 3,
#  'AbtiLibaan': 1,
#  'yatesbaz': 1,
#  'Nonameman999': 1,
#  'dhanishbn': 1,
#  'ATHE1STP0WER': 1,
#  'ItsRadioPolice': 1,
#  'm67freeman1': 1,
#  'bluedelta01': 1,
#  'Latics': 2,
#  'DebraLynnhendr1': 1,
#  'Rita27352598': 1,
#  'tweetcarrieann': 1,
#  'dburns1972': 2,
#  'DadPushy': 1,
#  'TimesRadio': 1,
#  'AmolPartridge': 2,
#  'PaulJoseBrain': 7,
#  'Furzpig': 4,
#  'keithbristoluk': 3,
#  'DonnaJa72630466': 4,
#  'lyndied1': 1,
#  'Punker_434': 1,
#  'thelastoftheV8s': 2,
#  'TroyTempest14': 2,
#  'LaneButts': 2,
#  'Stevemartin3804': 1,
#  'Kayyvon65': 2,
#  'BlueChipIT': 2,
#  'CounsellMitch': 2,
#  'Pauline_IG1': 1,
#  'Jollyanna7': 1,
#  'BaileyandWillow': 4,
#  'H6Pete': 1,
#  'jimmyboyjohnsen': 1,
#  'BryanRadford6': 2,
#  'c36get': 1,
#  'lolzamapop': 1,
#  'ShaunBaileyUK': 170,
#  'cristo': 1,
#  'Cristo': 1,
#  'annsilva14': 11,
#  'biggeorgie8': 1,
#  'freed0m2019': 3,
#  'Elizabe79841114': 5,
#  'hulkthemonk': 1,
#  'ingall_michele': 7,
#  'freelander547': 5,
#  'TMTT2015': 1,
#  'polytwonk': 8,
#  'wisteriawitch': 9,
#  'Cecilysaunder18': 2,
#  'MrJamesGalloway': 1,
#  'CharlieAl5': 1,
#  'CaptnCrash': 1,
#  'GrahamSanders9': 1,
#  'Dizzylizzie19': 4,
#  'woodsmoke14': 2,
#  'Rick_martin1988': 1,
#  'hirdygurdy': 1,
#  'nocylad': 3,
#  'mrrobertgreyson': 1,
#  'joncraig': 1,
#  'nickward89': 1,
#  'kingsmaz3': 1,
#  'cornishpastylo1': 1,
#  'ARNRCPNB': 1,
#  'Glentity': 1,
#  'ShanShambles': 1,
#  'Trevor45147961': 5,
#  'enuffsa1d': 23,
#  'TomCovenent': 2,
#  'Marleymints': 1,
#  'FedFin090': 3,
#  'Tel0072000': 6,
#  'Optimiste_sans': 6,
#  'sallybaloo': 2,
#  'langleyjilly': 2,
#  'bluewezzie': 1,
#  'Whetstonesdp': 3,
#  'SDPhq': 2,
#  'MoLovatt': 3,
#  'SDP_Chris': 10,
#  'BarbuUn': 8,
#  'Sledgeh63514792': 11,
#  'Twits_all_good': 1,
#  'etbusby': 9,
#  'MartinDn1001': 1,
#  'Jboy1878': 2,
#  'RichardKing633': 1,
#  'IainSim55659177': 1,
#  'paul43471534': 4,
#  'Carla32958764': 1,
#  'MOB51': 3,
#  'Ross_coP': 1,
#  'PotterWhiting': 1,
#  'John197914': 5,
#  'dstlouislittle5': 1,
#  'MFM_2696': 1,
#  'BreakawayOrigin': 3,
#  'JohnsonKarol': 2,
#  'LeaveHQ': 9,
#  'razorsharpe09': 2,
#  'kprfc84': 1,
#  'DEEP_GLAMORGAN8': 1,
#  'Abbegillen': 1,
#  'GothNemi': 1,
#  'waf529': 1,
#  'BillDrysdale6': 1,
#  'RebelForest1': 1,
#  'JeaniefaetroonJ': 7,
#  'steventhilton63': 1,
#  'J_Sikas': 1,
#  'Gingerman2011': 1,
#  'Rax230': 6,
#  'KoolKat1025': 912,
#  'BBCBreaking': 2,
#  'pritipatel': 64,
#  'DebbieE46116279': 1,
#  'BoutYeGuys': 1,
#  'dyer_pj': 3,
#  'brianward19': 1,
#  'DelardoKelle': 1,
#  'SIMON32445788': 9,
#  'JohnNE14ST': 1,
#  'lencobb3': 3,
#  'Tyr533': 3,
#  'ManUtd_class92': 1,
#  'Phil_Osophi': 2,
#  'REP57910897': 4,
#  'fearnsterry': 1,
#  'Georgin40427121': 2,
#  'TaskerDavid': 3,
#  'Chantalxox10': 1,
#  'PaulSwampyMarsh': 1,
#  'norfolkingood65': 2,
#  'iempow3r': 11,
#  'martinpgriff': 18,
#  'OneBigCommunity': 33,
#  'Nadi': 17,
#  'SteveChalke': 18,
#  'SmartSocialLDN': 32,
#  'AlexAtherton100': 18,
#  'DTTlondon': 35,
#  'HopeCollective2': 32,
#  'LibPeck': 21,
#  'SheriffFord': 1,
#  'letsget_talking': 10,
#  'crazymadscot': 1,
#  'RNRAF1': 1,
#  'paulpm38488769': 2,
#  'ZoranTrisic3': 1,
#  'DWMcIntyre_': 1,
#  'luddym': 2,
#  'scoobydo178': 1,
#  'marcus18633415': 6,
#  'trecregin': 1,
#  'GK09887': 1,
#  'GiletGirl': 4,
#  'frankie171717': 11,
#  'LSW12612672511': 52,
#  'tugcectnkaya': 1,
#  'JeffCort5': 1,
#  'zihinselorgazm': 1,
#  'MrsOakley67': 3,
#  'Anndav8': 6,
#  'WrestleAFC4Life': 5,
#  'NipHolmes': 1,
#  'chat2steve': 1,
#  'Tothemo83592350': 1,
#  'zie10120678': 1,
#  'GregTruman4': 1,
#  'LoonyLobster': 4,
#  'PeterMcC66': 4,
#  'BIMARCHSERVICES': 1,
#  'slippingawayto': 1,
#  'donifordace': 2,
#  'markeast8': 2,
#  'antianti69': 1,
#  'bentcoppper': 1,
#  'flowerpotz1': 8,
#  'IHirle': 1,
#  'Cuts79': 1,
#  'Amphlettvilla2': 1,
#  'CarolLovesTosh': 1,
#  'NICK26215': 2,
#  'KatySei': 1,
#  'K62615': 3,
#  'DowRonnie': 1,
#  'john_bromfield': 5,
#  'PMeldrew': 2,
#  'KingscottDawn': 1,
#  'KathrynBuxton2': 2,
#  'Cassy6000': 6,
#  'davidofhook': 1,
#  'gbutiri': 1,
#  '58_LYNDYLOU': 1,
#  'SMovitz': 1,
#  'WycombeMariner': 1,
#  'Omicron48466789': 3,
#  'NeilFromNorge': 1,
#  'TedDitchburnNNP': 1,
#  'SheelaghG': 6,
#  'HarrisonHickma1': 4,
#  'lesleyd59': 1,
#  'Fihel': 1,
#  'kew79': 1,
#  'wba434': 2,
#  'deans_coleen': 6,
#  'alexmassie': 1,
#  'ChristopherMN8': 1,
#  'RWS_UK': 1,
#  'y_lord': 1,
#  'IstvanBalog2': 1,
#  'FrontKorg': 1,
#  'pubbypaul': 3,
#  'quagmireisablue': 1,
#  'jeanlaydon': 1,
#  'nananaha21': 2,
#  'afagerbakke': 6,
#  'martynwebster6': 1,
#  'petitejean1': 2,
#  'Glen_Maney': 1,
#  'TeaLiptons': 1,
#  'stevejbudd': 2,
#  'annebarlow21': 3,
#  'daviediehard': 3,
#  'SueStyles1': 1,
#  'Lorraineninorc': 2,
#  'MintIrate': 1,
#  'Happyclapper8': 1,
#  'weenell2014': 1,
#  'psykeo': 4,
#  'anxiousmillenn4': 1,
#  'GraceSeren': 1,
#  'christi46995357': 3,
#  'davemyopinion': 1,
#  'Linfield1641': 2,
#  'Urmel2011': 2,
#  'GiannaMarriotta': 1,
#  'tciowawaw': 2,
#  '_JF2017_': 1,
#  'GwynJon57053784': 1,
#  'realBlackInk': 1,
#  'KathyRivendell': 1,
#  'RudlandMichael': 1,
#  'joemars_316': 1,
#  'Henry87592035': 2,
#  'pumadoggy': 1,
#  'Noseystafford': 1,
#  'mmcmartin2': 1,
#  'BirdiePint': 1,
#  'whisperair': 1,
#  'johncastel17': 1,
#  'alltalknowalk': 1,
#  'sixoftwo': 1,
#  'itsmeitsmeandy': 1,
#  'allxorxnothingx': 7,
#  'peach_russell': 3,
#  'zemblanity00': 1,
#  'ck1984ishere': 2,
#  'louisejonesjbj': 1,
#  'JuniorFindlay': 1,
#  'Willow19111410': 1,
#  'Margaretb2107': 10,
#  'dlovetx': 1,
#  'charliegee2020': 1,
#  'pab200uk': 1,
#  'medwar93': 10,
#  'DuncanRice1': 1,
#  'seanbaker87': 1,
#  'MakMak32390376': 1,
#  'DerekFairley3': 7,
#  'MungoMouthpiece': 1,
#  'BigPeteMac77': 1,
#  'Toughuy700': 2,
#  '___Paull___': 2,
#  'OverTheGil': 1,
#  'DanCohen313': 1,
#  'renney_david': 2,
#  'ladyjan67': 4,
#  'ThomesSara': 1,
#  'Weavemind': 1,
#  'Part_Saxon': 1,
#  'davestock18': 8,
#  'dsherwoodx2': 1,
#  'teamgriffiths': 1,
#  'martinpalmer351': 5,
#  'cowboysgirl1975': 1,
#  'Praeceps69': 6,
#  'cambrianguy': 4,
#  'boyden31': 1,
#  'YisraelChaiAdam': 1,
#  'rowsell_ian': 2,
#  'magenta_17': 1,
#  'jemevans': 1,
#  'thejoedoe1': 2,
#  'TraceyA54242410': 6,
#  'ErrolStock': 4,
#  'Patrick94784166': 2,
#  'mdc_1': 1,
#  'deborah1874': 4,
#  'PrancingHound': 5,
#  'frantruth': 2,
#  'freak_mick': 1,
#  'j_consilio': 4,
#  'LRBVirtualPA': 2,
#  '56Rainman': 1,
#  'waynelsworth': 1,
#  'thompson2_d': 2,
#  'antapaws1': 3,
#  'jadaz76': 3,
#  'THCmagic': 1,
#  'Wilkingshire': 3,
#  'BillyKi88394399': 2,
#  'SensibleYorks': 1,
#  'SureshBza': 1,
#  'robbymcnob': 1,
#  'aladinsain': 1,
#  'Paul66153553': 1,
#  'hiredgnu': 1,
#  'pat_morgan61': 1,
#  'Allez_oops': 1,
#  'HelenaPigott': 5,
#  'louhaley': 1,
#  'hootymcboob1': 1,
#  'TheRealVadea': 1,
#  'DexterLibre': 1,
#  'davesdogdrives': 1,
#  'BaconGengis': 1,
#  'BunnyPeculiar': 3,
#  'flynn6062': 1,
#  'El_Hxmbre': 1,
#  'gatchy3_': 1,
#  'TrappyBear': 1,
#  'BarrieCrampton': 1,
#  'z_chrissie': 11,
#  'StuartHarrower': 2,
#  'macnahgalla': 2,
#  'LlareggubJ': 5,
#  'Johnny_Logo': 1,
#  'AliceCuriouser2': 4,
#  'A_0_1_0_A': 1,
#  'hippocrates16': 1,
#  'La_Abejita_': 4,
#  'suprsilentdave': 1,
#  'jones27_susan': 11,
#  'JamesZychon': 1,
#  'GaryCar17994385': 3,
#  'twtistired': 1,
#  'NobbsPaddy': 11,
#  'StrugglesClass': 11,
#  'greeksteve': 1,
#  'GunzelTheWorld': 5,
#  '1oldGersdad': 1,
#  'LindaJe79892317': 2,
#  'JC26719401': 1,
#  'zebedee_brazell': 1,
#  'PragmaticPicks': 1,
#  'bennettdanny31': 1,
#  'DanT40192': 5,
#  'Mar10LG2': 1,
#  'ManLikeTan': 2,
#  'maeve41963761': 1,
#  'DoloresTom27': 9,
#  'Leo_uk_001': 3,
#  'Huutchy': 5,
#  'RobbieTwts': 1,
#  'murrayjohns': 1,
#  'DJJASONJOY1': 1,
#  'DrJonnyO': 1,
#  'LJotnar': 1,
#  'WearsTheFoxHat_': 2,
#  'yately9320': 1,
#  '_Alex_Longbard_': 1,
#  'Everythingsgoi2': 1,
#  'ali_pam': 1,
#  'bomber1872': 1,
#  'NickBuckleyMBE': 1,
#  'southsideofmcr': 1,
#  'pmevans5': 6,
#  'mosudeen': 1,
#  'JamboAldo': 1,
#  'scottf646': 2,
#  'the_cynical1': 1,
#  'NixJPayne': 5,
#  'MISHA90': 11,
#  'GlobalBritain21': 32,
#  'alan_lingwood': 5,
#  'SkyeBlue71': 1,
#  'KGBlonde59': 2,
#  'PupspurJeanette': 1,
#  'NickMalyon1': 1,
#  'Sambola84': 5,
#  'JackKaj3': 1,
#  'ESLTeac16885695': 1,
#  'Kennedy25405368': 10,
#  'stuart4britain': 1,
#  'HardingWade': 1,
#  'BrexitFoxy': 3,
#  'Blueste35650715': 2,
#  'DeeJarv34798927': 3,
#  'SeddazIHateThis': 1,
#  'Memnon71011': 1,
#  'stuffybubbles7': 1,
#  'muirsy1': 2,
#  'KevinAr63351894': 1,
#  'sandra4646': 9,
#  'Cstorm1166': 1,
#  'Kenmorrey6': 18,
#  'CPurposer': 4,
#  'AkkadSecretary': 1,
#  'DottiMillotti': 1,
#  'MrMeh70237637': 1,
#  'LangdaleLad': 1,
#  'GordonMcwhin': 1,
#  'Ludden123': 1,
#  'igfield73': 1,
#  'scrivo35': 1,
#  'DaveBoden8': 2,
#  'stevenalfh': 1,
#  'lewismj_waioeka': 1,
#  'gespachio1958': 2,
#  'Wazzara': 7,
#  'PaulCurby': 1,
#  'Bigg_Daddy_O': 1,
#  'roberthurley': 1,
#  'PrivateParts16': 3,
#  'TrumpCsc': 2,
#  'RosemaryKirk': 2,
#  '_jimmcneill': 1,
#  'BackwardWorldj2': 2,
#  'dannypuk2': 6,
#  'TheSandyLaner1': 4,
#  'edglasgow59': 1,
#  'Liberal2RedPill': 1,
#  'chunkylover25': 1,
#  'Jessica191965': 1,
#  'hughzdoyle7777': 2,
#  'stew1878': 2,
#  'rewonderingknow': 1,
#  'SPlummage': 1,
#  'JolyonMaugham': 2,
#  '55andcounting55': 1,
#  'RosyKnight': 1,
#  'jimamallen': 1,
#  'michael_hallatt': 1,
#  'iharding51': 2,
#  'KevW1962': 1,
#  'thackeray_p': 2,
#  'MonaLisaCroydon': 12,
#  'LNKcharity': 21,
#  'MJMC1690': 1,
#  'Bill_Cameron': 1,
#  'AlgonquinWhisky': 1,
#  'PaulHay76522951': 1,
#  'weekgeek24': 1,
#  'MrWasnt': 2,
#  'PhilH23': 1,
#  'moasxhweelal': 1,
#  'skepthai': 1,
#  'Gromule': 1,
#  'ludicluddite': 1,
#  'langley_will': 1,
#  'LicityTrip': 1,
#  'KerrAvonB7': 6,
#  'jordygreaves': 1,
#  'RInkson': 1,
#  'rockapepolitics': 5,
#  'LBCbackOnDAB': 1,
#  'Stewart62911094': 1,
#  'screamingspuds': 3,
#  'DaveWdave1': 2,
#  'DavidTh1965': 1,
#  'nattuurlijk': 5,
#  'DianeHu54605701': 1,
#  'TheUKObserver': 3,
#  'FeistyRealist': 1,
#  'MrMookieMoo': 1,
#  'andy_robo69': 1,
#  'FatherFatigued': 1,
#  'Carol22829672': 1,
#  'SarahJa28484793': 1,
#  'yorks_donny': 1,
#  ...}

# %%
# the keys are the user_id
nodelist = list(G.nodes.keys())
print(nodelist[:10])
# Out:
# ['myerschrismyer1', 'LeslieH24367191', 'emilysheffield', 'NaheedMajeed', 'standardnews', 'basilewitch', 'Short2Cjs', 'DeanCowcher', 'sonya_annie', 'OliverSteinme16']

# %%
# each node is itself a dictionary with node attributes as key,value pairs
print(type(G.nodes[nodelist[3]]))
print(G.nodes[nodelist[3]])
# Out:
# <class 'dict'>
# {'name': 'NaheedMajeed', 'degree': 6}

# %%
from operator import itemgetter
from networkx.algorithms import community 

sorted_degree = sorted(degree_dict.items(), key=itemgetter(1), reverse=True)

# %%
print("Top 20 nodes by degree:")
for d in sorted_degree[:20]:
    print(d)
# Out:
# Top 20 nodes by degree:
# ('KoolKat1025', 912)
# ('James_Thorburn', 858)
# ('SadiqKhan', 796)
# ('LeoKearse', 635)
# ('LeslieH24367191', 573)
# ('MayorofLondon', 556)
# ('LeaveEUOfficial', 542)
# ('GBNEWS', 349)
# ('BrexitBassist', 324)
# ('PoliticsJOE_UK', 321)
# ('standardnews', 302)
# ('daikhood', 301)
# ('PoliticsForAlI', 294)
# ('mariannaspring', 294)
# ('MickeyD44314901', 275)
# ('PrisonPlanet', 275)
# ('Independent', 264)
# ('talkRADIO', 263)
# ('LBC', 261)
# ('ActivePatriotUK', 253)

# %%
betweenness_dict = nx.betweenness_centrality(G) # Run betweenness centrality
eigenvector_dict = nx.eigenvector_centrality(G) # Run eigenvector centrality

# Assign each to an attribute in your network
nx.set_node_attributes(G, betweenness_dict, 'betweenness')
nx.set_node_attributes(G, eigenvector_dict, 'eigenvector')

# %%
sorted_betweenness = sorted(betweenness_dict.items(), key=itemgetter(1), reverse=True)

print("Top 20 nodes by betweenness centrality:")
for b in sorted_betweenness[:20]:
    print(b)

# %%
#First get the top 20 nodes by betweenness as a list
top_betweenness = sorted_betweenness[:20]

#Then find and print their degree
for tb in top_betweenness: # Loop through top_betweenness
    degree = degree_dict[tb[0]] # Use degree_dict to access a node's degree, see footnote 2
    print("Name:", tb[0], "| Betweenness Centrality:", tb[1], "| Degree:", degree)

# %%
H = nx.Graph(G) # need to convert to undirected graph to use greedy_modularity

communities = community.greedy_modularity_communities(H)

# %%
modularity_dict = {} # Create a blank dictionary
for i,c in enumerate(communities): # Loop through the list of communities, keeping track of the number for the community
    for name in c: # Loop through each person in a community
        modularity_dict[name] = i # Create an entry in the dictionary for the person, where the value is which group they belong to.

# Now you can add modularity information like we did the other metrics
nx.set_node_attributes(G, modularity_dict, 'modularity')

# %%
df_community_dict = pd.DataFrame(list(modularity_dict.items()),columns = ['screen_name','class_id']) 
class_list = df_community_dict.class_id.unique()

print("Number of different communities = {} ".format(len(class_list)))

df_community_dict_agg = df_community_dict.groupby('class_id').count()

comm_count = 10
print("\nTop {} communities, by number of members".format(comm_count))
df_community_dict_agg.head(comm_count)

# %%
from matplotlib import pyplot as plt

def print_class_members(class_num, count):

    # First get a list of just the nodes in that class
    class_id = [n for n in G.nodes() if G.nodes[n]['modularity'] == class_num]

    # Then create a dictionary of the eigenvector centralities of those nodes
    class_eigenvector = {n:G.nodes[n]['eigenvector'] for n in class_id}

    # Then sort that dictionary and print the first 5 results
    class_sorted_by_eigenvector = sorted(class_eigenvector.items(), key=itemgetter(1), reverse=True)

    print("\n<--- Modularity Class {} Sorted by Eigenvector Centrality, top {} values --->".format(class_num, count))
    for node in class_sorted_by_eigenvector[:count]:
        print("Name:", node[0], "| Eigenvector Centrality:", node[1])
        
    my_subgraph = G.subgraph(class_id)
    
    plt.figure()
    nx.draw(my_subgraph)
    plt.show()
        
print_class_members(0, 10)
print_class_members(1, 10)
print_class_members(2, 10)
print_class_members(3, 10)
print_class_members(4, 10)

# %% [markdown]
# ## carry on with bovet

# %%
# edges are contained in a EdgeView with a set-like interface
print(type(G.edges))
print(G.edges())
# Out:
# <class 'networkx.classes.reportviews.OutEdgeView'>
# [('myerschrismyer1', 'LeslieH24367191'), ('myerschrismyer1', 'BrexitPartridge'), ('myerschrismyer1', 'LeaveEUOfficial'), ('LeslieH24367191', 'MickeyD44314901'), ('LeslieH24367191', 'DJBURNS_was'), ('LeslieH24367191', 'James_Thorburn'), ('LeslieH24367191', 'SadiqKhan'), ('LeslieH24367191', 'benhabib6'), ('LeslieH24367191', 'ShaunBaileyUK'), ('LeslieH24367191', 'LeaveEUOfficial'), ('LeslieH24367191', 'MayorofLondon'), ('LeslieH24367191', 'suemitch2017'), ('LeslieH24367191', 'GBNEWS'), ('emilysheffield', 'NaheedMajeed'), ('emilysheffield', 'standardnews'), ('emilysheffield', 'nicholascecil'), ('emilysheffield', 'EveningStandard'), ('NaheedMajeed', 'emilysheffield'), ('NaheedMajeed', 'standardnews'), ('standardnews', 'Sadiq'), ('standardnews', 'SadiqKhan'), ('basilewitch', 'Short2Cjs'), ('basilewitch', 'Keir_Starmer'), ('basilewitch', 'RichardBurgon'), ('basilewitch', 'rec777777'), ('basilewitch', 'brexitblog_info'), ('basilewitch', 'MickeyD44314901'), ('basilewitch', 'telegraph'), ('basilewitch', 'TegoArcanaDei'), ('basilewitch', 'LeaveEUOfficial'), ('basilewitch', 'GBullstein'), ('basilewitch', 'GiftCee'), ('DeanCowcher', 'LeslieH24367191'), ('DeanCowcher', 'MickeyD44314901'), ('DeanCowcher', 'telegraph'), ('DeanCowcher', 'theabd'), ('DeanCowcher', 'Drivers_London'), ('DeanCowcher', 'TflTruth'), ('DeanCowcher', 'cristo_radio'), ('DeanCowcher', 'GitTheBiker'), ('sonya_annie', 'Short2Cjs'), ('sonya_annie', 'KoolKat1025'), ('sonya_annie', 'LeslieH24367191'), ('OliverSteinme16', 'Kalimeralynn'), ('OliverSteinme16', 'Bravescott69'), ('OliverSteinme16', 'LeaveEUOfficial'), ('Kalimeralynn', 'LeslieH24367191'), ('Bravescott69', 'LeaveEUOfficial'), ('Bravescott69', 'GreatUK77'), ('GM_RayKeene', 'LeslieH24367191'), ('GM_RayKeene', 'BrexitBassist'), ('Howwee', 'LeslieH24367191'), ('Howwee', 'NKrankie'), ('Howwee', 'MickeyD44314901'), ('Howwee', 'BrexitBassist'), ('Howwee', 'KhanMustGo'), ('Howwee', 'James_Thorburn'), ('Howwee', 'GBNEWS'), ('bramble__jam', 'UncleTrash'), ('Sheilamayparke1', 'boblister_poole'), ('Sheilamayparke1', 'KoolKat1025'), ('Sheilamayparke1', 'LeslieH24367191'), ('boblister_poole', 'SadiqKhan'), ('boblister_poole', 'benhabib6'), ('John27454952', 'linmeitalks'), ('John27454952', 'mrjamesob'), ('John27454952', 'LBC'), ('John27454952', 'rakibehsan'), ('John27454952', 'spikedonline'), ('darlingvivien', 'LeslieH24367191'), ('darlingvivien', 'LTHlondon'), ('darlingvivien', 'ByrneBarry'), ('darlingvivien', 'ActivePatriotUK'), ('darlingvivien', 'daikhood'), ('darlingvivien', 'Tricky9993'), ('darlingvivien', 'standardnews'), ('darlingvivien', 'ShaunBaileyUK'), ('becky10002', 'LBC'), ('LBC', 'NickFerrariLBC'), ('JoRichardsKent', 'Nic'), ('JoRichardsKent', 'NickFerrariLBC'), ('JoRichardsKent', 'LBC'), ('NickFerrariLBC', 'LBC'), ('RosettaTickner', 'boblister_poole'), ('RosettaTickner', 'LeslieH24367191'), ('RosettaTickner', 'MickeyD44314901'), ('RosettaTickner', 'darrengrimes_'), ('RosettaTickner', 'KateBolger7'), ('RosettaTickner', 'James_Thorburn'), ('Janet42957897', 'LeslieH24367191'), ('Janet42957897', 'KhanMustGo'), ('Janet42957897', 'NKrankie'), ('Janet42957897', 'metpoliceuk'), ('Janet42957897', 'BrexitBassist'), ('Janet42957897', 'James_Thorburn'), ('Janet42957897', 'Jonik32352469'), ('KarlJiAllen', 'Short2Cjs'), ('KarlJiAllen', 'LeoKearse'), ('KarlJiAllen', 'NKrankie'), ('KarlJiAllen', 'PrisonPlanet'), ('KarlJiAllen', 'BrexitBassist'), ('KarlJiAllen', 'LeaveEUOfficial'), ('KarlJiAllen', 'OhBrokenBritain'), ('KarlJiAllen', 'LeslieH24367191'), ('neerajsanatani1', 'LeoKearse'), ('Morris2906', 'Short2Cjs'), ('Morris2906', 'KhanMustGo'), ('Morris2906', 'ShaunBaileyUK'), ('Morris2906', 'GLAConservative'), ('Morris2906', 'BBCSounds'), ('Morris2906', 'nikkiar'), ('Morris2906', 'Councillorsuzie'), ('Morris2906', 'CllrEdwardSmith'), ('Morris2906', 'AndrewBoff'), ('Morris2906', 'IlfordRecorder'), ('527_thatch', 'SadiqKhan'), ('philrevis', 'LeslieH24367191'), ('Susanmerryweath', 'LeslieH24367191'), ('Susanmerryweath', 'LeaveEUOffici ...

# %%
# we can see all the edges going out of this node
# each edge is a dictionary inside this dictionary with a key 
# corresponding to the target user_id
e = G.out_edges(nodelist[4], data=True)
print(nodelist[4])
print(e)
# Out:
# standardnews
# [('standardnews', 'Sadiq', {'tweet_id': 1420730171980668933}), ('standardnews', 'SadiqKhan', {'tweet_id': 1421157093206372362})]

# %%
# we can iterate over the out-edges 
for s,t,data in e:
    print(s,t,data)
# Out:
# standardnews Sadiq {'tweet_id': 1420730171980668933}
# standardnews SadiqKhan {'tweet_id': 1421157093206372362}

# %%
G.number_of_nodes()

# %%
G.number_of_edges()

# %%
# dictionary with the degree of all nodes
all_degrees = [G.degree(n) for n in nodelist] # this is the degree for undirected edges
in_degrees = [G.in_degree(n) for n in nodelist]
out_degrees = [G.out_degree(n) for n in nodelist]

# %%
# average degree
2*G.number_of_edges()/G.number_of_nodes()

# %%
import numpy as np
np.array(all_degrees).mean()

# %%
np.array(in_degrees).mean()

# %%
np.array(out_degrees).mean()

# %%
# we want to make a list with (user_id, username, degree) for all nodes
degree_node_list = []
for node in nodelist:
    degree_node_list.append((node, G.nodes[node]['name'], G.degree(node)))
    
print('Unordered user, degree list')    
print(degree_node_list[:10])

# sort the list according the degree in descinding order
degree_node_list = sorted(degree_node_list, key=lambda x:x[2], reverse=True)
print('Ordered user, degree list')    
print(degree_node_list[:10])
# Out:
# Unordered user, degree list
# [('myerschrismyer1', 'myerschrismyer1', 3), ('LeslieH24367191', 'LeslieH24367191', 573), ('emilysheffield', 'emilysheffield', 24), ('NaheedMajeed', 'NaheedMajeed', 6), ('standardnews', 'standardnews', 302), ('basilewitch', 'basilewitch', 11), ('Short2Cjs', 'Short2Cjs', 9), ('DeanCowcher', 'DeanCowcher', 8), ('sonya_annie', 'sonya_annie', 3), ('OliverSteinme16', 'OliverSteinme16', 4)]
# Ordered user, degree list
# [('KoolKat1025', 'KoolKat1025', 912), ('James_Thorburn', 'James_Thorburn', 858), ('SadiqKhan', 'SadiqKhan', 796), ('LeoKearse', 'LeoKearse', 635), ('LeslieH24367191', 'LeslieH24367191', 573), ('MayorofLondon', 'MayorofLondon', 556), ('LeaveEUOfficial', 'LeaveEUOfficial', 542), ('GBNEWS', 'GBNEWS', 349), ('BrexitBassist', 'BrexitBassist', 324), ('PoliticsJOE_UK', 'PoliticsJOE_UK', 321)]

# %%
# we need to import matplolib for making plots
# and numpy for numerical computations
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Network components
# Connected components are a subset of nodes in which each node has a minimum of one link with another node in the same subset, and any node that is a member of 'this' subset is not linked to any nodes external to the subset.
#
# In addition, for <b> directed </b> graphs we can define two types of connected components:
# - Weakly connected components, (WCC): maximal set of nodes where there exists a path in at least one direction between each pair of nodes.
# - Strongly connected components, (SCC): maximal set of nodes where there exists a path in both directions between each pair of nodes.
#
# And, within these categories we can additionally identify the weakly connected giant (WCGC), which is the largest of the weakly connected components and the strongly connected giant (SCGC), which is the largest of the strongly connected components. In effect these are the largest subgraphs within the network. Bovet et al illustrate this (incorrectly, for SCGC given arrows aren't two way) as follows:
#
# <img src="WCGC-SCGC.png">

# %% [markdown]
# ## Strongly connected components

# %%
# this returns a list of set of nodes belonging to the 
# different (strongly) connected components
components_strong = list(nx.strongly_connected_components(G))

# sort the component according to their size
components_strong = list(sorted(components_strong, key=lambda x:len(x), reverse=True))

# make a list with the size of each component
comp_sizes_strong = []
for comp in components_strong:
    comp_sizes_strong.append(len(comp))
    
print("number of strong components: {}".format(len(comp_sizes_strong)))

print("sizes of the ten largest components: {}".format(comp_sizes_strong[:20]))

# %%
def draw_strongly_connected(idx):

    largest_comp_strong = components_strong[idx]
    LCC_strong = G.subgraph(largest_comp_strong)

    print("number of components in LCC[{}] = {}".format(idx, LCC_strong.number_of_nodes()))

    # let's plot the degree distribution inside the LCC
    degrees = [LCC_strong.degree(n) for n in LCC_strong.nodes()]
    print("number of degrees for each node within LCC[{}] = {}\n".format(idx, degrees))
    
    # add weights to the edges based on how many times they are traversed
    print("Weight of edges between each node:\n")
    
    for u, v, d in LCC_strong.edges(data=True):
        d['weight'] = 1
    for u,v,d in LCC_strong.edges(data=True):
        print (u,v,d)
    
    ## <--- now look at centrality
    betweenValues = nx.betweenness_centrality(LCC_strong)
    
    # betweenValues is a dictionary, let's get the values and keys in separate lists
    values = list(betweenValues.values())
    keys = list(betweenValues.keys())
    
    # find the index of the node with highest betweeness centrality
    highestIndex = np.argmax(values)
    
    #Uses solution in the documentation: https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.algorithms.components.connected.connected_component_subgraphs.html
    
    print('\n <---- centrality and clustering measures -------> \n')
    print("The node id ", keys[highestIndex], " has the centrality degree of ", values[highestIndex])

    overallAverage = []
    # now on to looking at clustering coefficients
    for i in range(0, countComps):
        clustCoeff = nx.clustering( connectedSubgraphs[i])
        coeffVals = list(clustCoeff.values())
        overallAverage.append(np.average(coeffVals))
    
    print ("Average clustering coefficent is: ", np.average(overallAverage))

    ## <--- end of this
    
    
    plt.figure()
    nx.draw_networkx(LCC_strong)
    plt.show()

# %%
range_limit = 5
for n in range(range_limit):
    draw_strongly_connected(n)

# %% [markdown]
# ## end of strongly connected components
# - need to comment on interesting not necessarily for the size of the strong components but mostly because of the prominence of their members in other communities - look at that as part of the weakly connected components plus also the community

# %%
# this returns a list of set of nodes belonging to the 
# different (weakly) connected components
components = list(nx.weakly_connected_components(G))

# sort the component according to their size
components = list(sorted(components, key=lambda x:len(x), reverse=True))

# %%
# make a list with the size of each component
comp_sizes = []
for comp in components:
    comp_sizes.append(len(comp))

# %%
# plot the histogram of component sizes
hist = plt.hist(comp_sizes, bins=100)

# %%
# histogram with logarithmic y scale
hist = plt.hist(comp_sizes, bins=100, log=True)
tx = plt.xlabel('component size')
ty = plt.ylabel('number of components')

# %%
# sizes of the ten largest components
comp_sizes[:10]

# %%
# let's make a new graph which is the subgraph of G corresponding to 
# the largest connected component
# let's find the largest component
largest_comp = components[2]
LCC = G.subgraph(largest_comp)

# %%
G.number_of_nodes()

# %%
LCC.number_of_nodes()

# %%
# let's plot the degree distribution inside the LCC
degrees = [LCC.degree(n) for n in LCC.nodes()]
degrees.sort(reverse=True)
degrees

# %%
plt.figure(figsize=(10,10))
nx.draw_networkx(LCC)
plt.show()

# %%
degree_array = np.array(degrees)
hist = plt.hist(degree_array, bins=100)

# %%
# using logarithmic scales
hist = plt.hist(degree_array, bins=100, log=True)
plt.xscale('log')

# %%
# logarithmic scale with logarithmic bins
N, bins, patches = plt.hist(degree_array, bins=np.logspace(0,np.log10(degree_array.max()+1), 20), log=True)
plt.xscale('log')
tx = plt.xlabel('k - degree')
ty= plt.ylabel('number of nodes')

# %%
# Degree probability distribution (P(k))

# since we have logarithmic bins, we need to
# take into account the fact that the bins 
# have different lenghts when normalizing
bin_lengths = np.diff(bins) # lenght of each bin

summ = np.sum(N*bin_lengths)
normalized_degree_dist = N/summ

# check normalization:
print(np.sum(normalized_degree_dist*bin_lengths))

hist = plt.bar(bins[:-1], normalized_degree_dist, width=np.diff(bins))
plt.xscale('log')
plt.yscale('log')
tx = plt.xlabel('k (degree)')
ty = plt.ylabel('P(k)')

# %% [markdown]
# ## Find most important Tweeters using Page Rank
# PageRank is a generalisation of Google's websearch algorithm, which was originally a method for returning the most important web pages for a given search term. It defined importance as the page which - need to talk about teleporting and surfer stuff - reference this bloke: Gleich, D.F., 2015. PageRank beyond the web. Siam Review, 57(3), pp.321-363.
#
# Also then look at from the perspective of centrality as this tells us which nodes(pages) have most edges in or out

# %%
#teleportation probability
alpha = 0.15

#adjacency matrix
nodelist = list(G.nodes())
A = nx.to_numpy_array(G, nodelist=nodelist)

#diagonal matrix of out degrees
deg_out_vect = np.array([float(max(G.out_degree(n),1)) for n in nodelist])
D_out_inv = np.diag(1/deg_out_vect)

# teleportation transition matrix
N = A.shape[1]
S = np.ones((N,N))*1/N

# full transition matrix
M = (1-alpha)*D_out_inv @ A + alpha*S

# for dangling nodes (nodes without out-edges), we force the random teleportation
dangling_nodes = np.where(A.sum(1) == 0)[0]
M[dangling_nodes,:] = S[dangling_nodes,:]

#initial walker distribution and 1st iteration
p_last = np.ones(N)*1/N
p = np.matmul(p_last, M)

# iterate until sufficient convergence
eps = 1.0e-8
i = 1
while np.linalg.norm(p - p_last, 2) > eps:
        p_last = p
        p = np.matmul(p, M)
        i += 1

print(i)

# %%
pg_ranking = np.array(np.argsort(p)[::-1])

pagerank_values = p[pg_ranking]
nodes_pagerank = [nodelist[r] for r in pg_ranking]
nodes_pagerank[:20]

# %%
names_pagerank = [G.nodes[n]['name'] for n in nodes_pagerank]
names_pagerank[:20]

# %% [markdown]
# ### Compare page rank with degree
# Top 20 nodes by degree:
# - ('KoolKat1025', 911)
# - ('LeoKearse', 629)
# - ('LeaveEUOfficial', 537)
# - ('SadiqKhan', 510)
# - ('MayorofLondon', 376)
# - ('BrexitBassist', 317)
# - ('PoliticsJOE_UK', 314)
# - ('mariannaspring', 294)
# - ('PoliticsForAlI', 240)
# - ('LBC', 235)
# - ('PrisonPlanet', 230)
# - ('NKrankie', 219)
# - ('talkRADIO', 210)
# - ('TJ_Knight', 192)
# - ('metpoliceuk', 171)
# - ('ashindestad', 170)
# - ('MickeyD44314901', 160)
# - ('DJBURNS_was', 160)
# - ('Independent', 160)
# - ('standardnews', 152)

# %%
hist = plt.bar(np.arange(p.shape[0]),np.sort(p)[::-1])
ty = plt.ylabel('PageRank value')
tx = plt.xlabel('PageRank ranking')

# %%
# pagerank is a probability density
pagerank_values.sum()

# %%
# draw the network of the top 5 nodes
plt.figure(figsize=(10,10))
nx.draw(G, nodelist=nodes_pagerank[:5], node_size=8000*pagerank_values[:5],width=0.5, arrows=False)
plt.show()

# %%
# First let's add the pagerank value as a node attribute
for n, pr in zip(nodes_pagerank,pagerank_values):
    if n in LCC:
        LCC.nodes[n]['page_rank'] = pr

# %%
nodes_pagerank[:5]
